# %% [markdown]
# # Extrayendo shapes
#
# Algo que probablemente te resulte obvio a estas alturas es que producir datos en RDF con una calidad adecuada requiere cierto esfuerzo de modelado y de mantenimiento. RDF, como propuesta tecnológica, no fuerza la estructura de los datos en ningún caso, pero si los datos no tienen estructuras homogéneas y contstantes, nuestros grafos RDF se vuelven inoperables, pues se vuelve extremadamente difícil producir consultas SPARQL apropiadas para obtener la información deseada. Estas estructuras deben ser planificadas cuidadosamente, tanto a nivel topológico como semántico. Esto es, hemos de tener e implementar un plan que nos indique qué tipo de entidades deberían relacionarse con qué otro tipo de entidades, y cuáles son las propiedades y clases específicas que describen y relacionan tales entidades.
#
# Los lenguajes de shapes (ShEx/SHACL) son una ayuda inestimable en ese sentido. Sirven tanto para describir esas estructuras como para detectar partes concretas del grafo donde las estructuras esperadas no se dan. Ambas cosas facilitan el mantenimiento y el aprovechamiento de los datos. No obstante, los esquemas ShEx/SHACL requieren un nuevo esfuerzo: hay que conocer bien el dominio para diseñarlos correctamente, hay que tener habilidad suficiente con la tecnología para escribirlos/utilizarlos, y hay que reescribirlos de forma paralela a al grafo en caso de que nuestro dominio/datos evolucionen. Es decir, si bien su utiidad es obvia, no podemos obviar que también es obvio que requieren aún un esfuerzo extra de mantenimiento que se añade al de mantener el propio grafo.
#
#
# Para ayudar en esa tarea, aparece software especializado en la creación automática de shapes a partir de contenido RDF existente. Podemos distinguir dos tipos de aproximaciones, no necesariamente disjuntas.
#
# Por un lado, algunas técnicas tratan de inferir shapes o mapear constraints presentes en conocimiento ontológico (T-BOX). Ejemplo: si se conoce que el rango de la propiedad vive_en es la clase Persona y el rango es la clase Vivienda, se podría inferir que la shapa asociada a la clase Persona tendrá una constraint que indica que se debe usar la propiedad vive_en para enlazar con nodos que conformen con la shape asociada a la clase vivienda. Sobre el papel, es una aproximación pulcra y con sentido, pero a menudo resulta insuficiente. Los usos concretos que cierto grafo de conocimiento hacen de una ontología suelen ser más específicos que las posibilidades de la ontología.
#
# Por otro lado, hay técnicas que trabajan a nivel de conocimiento de instancia (A-BOX). Minan el vecindario de nodos de ejemplo y tratan de extrapolar conclusiones generales de lo que observan. Es decir, no utilizan conocimiento ontológico sobre *cómo deberían ser el grafo*, sino cnocimiento empírico sobre *cómo se observa que es el grafo*. Por ejemplo: si se observa que todos los nodos de tipo persona (Ana, Jose, Juan, Laura...) se enlazan mediante la propiedad vive_en con exactamente un nodo que es de tipo Vivienda (URIs representando dónde viven personas concretas), entonces se podrá asumir que mi grafo se describe correctamente con una shape shape_Persona que apunta mediante la propiedad vive_en a nodos que conforman con la shape shape_Vivienda. De nuevo, sobre el papel, parece un enfoque efectivo. No osbtante, los resultados pueden tender a ser simplistas cuando se dan relaciones complejas entre datos complejas (con operadores lógicos), podría perderse parte de la riquieza del dominio si los datos observados no contienen todos los posibles casos, y requieren más tiempo de computo que las aproximaciones que utilizan conocimiento T-BOX, puesto que en escenarios reales suele haber muchos más datos anivel de instancia que a nivel de clase.
#
# Con todo, y a pesar que ninguna aproximación (ni la teórica combinación de ambas) asegura un resultado perfecto, este tipo de software facilita mucho la tarea de mantener esquemas de shapes.
#
# A continuación, se describe cómo realizar extracciones de shapes con la librería de Python más madura a día de hoy para esta tarea: sheXer. sheXer es un extractor de shapes basado en A-BOX, es decir, extrae conclusiones sobre hechos observados a nivel de instancia. La libreria ofrece una clase (Shaper) con un método (shex_graph) para extraer shapes, pero los parámetros usados en la construcción de esta clase permiten adpaptarse a diferentes contextos. Antes de utilizar sheXer, debes tener claras tus intenciones con respecto a varias cuestiones:
#
# * Tipo de entrada: fichero(s) local(es), ficheros remotos, grafo de rdflib, contenido expuesto en endpoint, contenido comprimido o no.
# * Tipo de salida a nivel de lenguaje: ShEx (sintaxis compacta ShExC) o SHACL (sintaxis turtle).
# * Tipo de salida a nivel de formato: salida a fichero, string, o JPG (como UML).
# * Agrupación de nodos objetivo. Comúnmente, cuáles son las clases de las que se quiere obtener una shape. Pero también se pueden hacer asociaciones de grupos de nodos específicos con una shape mediante el uso de shape maps.
#
# sheXer permite configurar muchos otros aspectos de la extracción, pero probablemente sean cuestiones que escapen a tus casos de uso iniciales. Consulta el repositorio de la librería para más información: https://github.com/weso/shexer
#
# En el repositorio también encontrarás un Jupyter con código de ejemplo para usar sheXer en diferentes situaciones contra el endpoint de Wikidata.
#
# A continuación se proporciona código de ejemplo que podrías adaptar a tus casos de uso:

# %%
# !git clone https://github.com/cursosLabra/miw_websem2425.git
# Out:
# Cloning into 'miw_websem2425'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 49 (delta 21), reused 35 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 61.63 KiB | 530.00 KiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# !pip install shexer
# Out:
# Collecting shexer
#   Downloading shexer-2.5.9-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: Flask in /usr/local/lib/python3.11/dist-packages (from shexer) (3.1.0)
# Collecting Flask-Cors (from shexer)
#   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting rdflib (from shexer)
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting SPARQLWrapper (from shexer)
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting wlighter (from shexer)
#   Downloading wlighter-1.0.1.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting plantuml (from shexer)
#   Downloading plantuml-0.3.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting python-xz (from shexer)
#   Downloading python_xz-0.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer) (1.9.0)
# Requirement already satisfied: httplib2 in /usr/local/lib/python3.11/dist-packages (from plantuml->shexer) (0.22.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib->shexer) (3.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from wlighter->shexer) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->Flask->shexer) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->wlighter->shexer) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->wlighter->shexer) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->wlighter->shexer) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->wlighter->shexer) (2025.1.31)
# Downloading shexer-2.5.9-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.2/169.2 kB 5.7 MB/s eta 0:00:00
# Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# Downloading plantuml-0.3.0-py3-none-any.whl (5.8 kB)
# Downloading python_xz-0.5.0-py3-none-any.whl (20 kB)
# Downloading rdflib-7.1.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.9/564.9 kB 22.2 MB/s eta 0:00:00
# Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Building wheels for collected packages: wlighter
#   Building wheel for wlighter (setup.py) ... done
#   Created wheel for wlighter: filename=wlighter-1.0.1-py3-none-any.whl size=5840 sha256=c7e1bcafd8932ce74f7a2270d04ef6af85f7c805cc7bcc77d2c1f8d9d05cc064
#   Stored in directory: /root/.cache/pip/wheels/a7/99/fc/827abe031e1eb32a25e3bda1affff5a8adccfecf52d5548425
# Successfully built wlighter
# Installing collected packages: rdflib, python-xz, wlighter, SPARQLWrapper, plantuml, Flask-Cors, shexer
# Successfully installed Flask-Cors-5.0.0 SPARQLWrapper-2.0.0 plantuml-0.3.0 python-xz-0.5.0 rdflib-7.1.3 shexer-2.5.9 wlighter-1.0.1

# %%
from shexer.shaper import Shaper
from shexer.consts import TURTLE_ITER

rdf_local_path = "/content/miw_websem2425/lab_sessions/books_data.ttl"

# Extracción de una shape asociada a cada clase con al menos alguna instancia en el grafo.

shaper = Shaper(graph_file_input=rdf_local_path,  # ruta local del grafo
                input_format=TURTLE_ITER,  # Formato de entrada TURTLE, pero con un parser no basado en rdflib.
                                           # const.TURTLE usa el parser de rdflib. La diferencia es que TURTLE_ITER
                                           # permite manejar grandes cargas de datos y no introduce espacios de nombres
                                           # por defecto.
                all_classes_mode=True, # Indica que queremos una shape por clase
                disable_comments=True) # Desactiva comentarios asociados a las shapes. Si no se indica esto, el esquema
                                       # de salida incluye anotaciones estadísticas.

result = shaper.shex_graph(string_output=True)  # Indica salida string. Hay parámetros para indicar salida UML o a fichero.

print(result)
# Out:
# PREFIX : <http://weso.es/shapes/>
#
# :Person
# {
#    <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>  [<http://schema.org/Person>]  ;
#    <http://xmlns.com/foaf/0.1/name>  <http://www.w3.org/2001/XMLSchema#string>  ;
#    <http://schema.org/birthDate>  <http://www.w3.org/2001/XMLSchema#date>  ;
#    <http://schema.org/nationality>  <http://www.w3.org/2001/XMLSchema#string>  ;
#    <http://schema.org/knows>  @:Person  ?
# }
#
#
# :Genre
# {
#    <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>  [<http://schema.org/Genre>]  ;
#    <http://schema.org/name>  <http://www.w3.org/2001/XMLSchema#string>
# }
#
#
# :Book
# {
#    <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>  [<http://schema.org/Book>]  ;
#    <http://purl.org/dc/terms/title>  <http://www.w3.org/2001/XMLSchema#string>  ;
#    <http://schema.org/author>  @:Person  ;
#    <http://schema.org/datePublished>  <http://www.w3.org/2001/XMLSchema#date>  ;
#    <http://schema.org/genre>  @:Genre  +;
#    <http://schema.org/ISBN>  <http://www.w3.org/2001/XMLSchema#string>  ;
#    <http://schema.org/publisher>  @:Organization  ;
#    <http://schema.org/translatedInto>  <http://www.w3.org/2001/XMLSchema#string>  ?
# }
#
#
# :Organization
# {
#    <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>  [<http://schema.org/Organization>]  ;
#    <http://schema.org/name>  <http://www.w3.org/2001/XMLSchema#string>
# }

# %%
from shexer.shaper import Shaper
from shexer.consts import TURTLE_ITER

rdf_local_path = "/content/miw_websem2425/lab_sessions/books_data.ttl"

namespaces_dict = {"http://www.w3.org/1999/02/22-rdf-syntax-ns#": "rdf",
                   "http://example.org/": "ex",
                   "http://www.w3.org/2001/XMLSchema#": "xsd",
                   "http://schema.org/" : "schema",
                   "http://xmlns.com/foaf/0.1/" : "foaf",
                   "http://purl.org/dc/terms/" : "dcterms"
                   }

# Mismo caso que el anterior, pero añadimos pares prefijo-espacio de nombres para obtener un resultado más "estético"

shaper = Shaper(graph_file_input=rdf_local_path,
                input_format=TURTLE_ITER,
                all_classes_mode=True,
                disable_comments=True,
                namespaces_dict=namespaces_dict) # Añadiendo este parámetro extra, los namespaces se incluirán en el resultado

result = shaper.shex_graph(string_output=True)

print(result)
# Out:
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX ex: <http://example.org/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX : <http://weso.es/shapes/>
#
# :Person
# {
#    rdf:type  [schema:Person]  ;
#    foaf:name  xsd:string  ;
#    schema:birthDate  xsd:date  ;
#    schema:nationality  xsd:string  ;
#    schema:knows  @:Person  ?
# }
#
#
# :Genre
# {
#    rdf:type  [schema:Genre]  ;
#    schema:name  xsd:string
# }
#
#
# :Book
# {
#    rdf:type  [schema:Book]  ;
#    dcterms:title  xsd:string  ;
#    schema:author  @:Person  ;
#    schema:datePublished  xsd:date  ;
#    schema:genre  @:Genre  +;
#    schema:ISBN  xsd:string  ;
#    schema:publisher  @:Organization  ;
#    schema:translatedInto  xsd:string  ?
# }
#
#
# :Organization
# {
#    rdf:type  [schema:Organization]  ;
#    schema:name  xsd:string
# }

# %%
from shexer.shaper import Shaper
from shexer.consts import TURTLE_ITER

rdf_local_path = "/content/miw_websem2425/lab_sessions/books_data.ttl"

namespaces_dict = {"http://www.w3.org/1999/02/22-rdf-syntax-ns#": "rdf",
                   "http://example.org/": "ex",
                   "http://www.w3.org/2001/XMLSchema#": "xsd",
                   "http://schema.org/" : "schema",
                   "http://xmlns.com/foaf/0.1/" : "foaf",
                   "http://purl.org/dc/terms/" : "dcterms"
                   }

# Mismo caso que el anterior, pero con estadísticas en el resultado. Esto nos permite saber datos sobre frecuencia que se observó
# cierto hecho o pistas de constraints que no llegaron al esquema final porque no conformaban con todos los nodos posibles.

shaper = Shaper(graph_file_input=rdf_local_path,
                input_format=TURTLE_ITER,
                all_classes_mode=True,
                disable_comments=False,  # Con esto a False (o no poniendo este parámetro) aparecen las estadísticas
                namespaces_dict=namespaces_dict)

result = shaper.shex_graph(string_output=True)

print(result)
# Out:
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX ex: <http://example.org/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX : <http://weso.es/shapes/>
#
# :Person
# {
#    rdf:type  [schema:Person]  ;                                # 100.0 %
#    foaf:name  xsd:string  ;                                    # 100.0 %
#    schema:birthDate  xsd:date  ;                               # 100.0 %
#    schema:nationality  xsd:string  ;                           # 100.0 %
#    schema:knows  @:Person  ?
#             # 66.66666666666666 % obj: @:Person. Cardinality: {1}
# }
#
#
# :Genre
# {
#    rdf:type  [schema:Genre]  ;                                 # 100.0 %
#    schema:name  xsd:string                                     # 100.0 %
# }
#
#
# :Book
# {
#    rdf:type  [schema:Book]  ;                                  # 100.0 %
#    dcterms:title  xsd:string  ;                                # 100.0 %
#    schema:author  @:Person  ;                                  # 100.0 %
#    schema:datePublished  xsd:date  ;                           # 100.0 %
#    schema:genre  @:Genre  +;                                   # 100.0 %
#             # 80.0 % obj: @:Genre. Cardinality: {1}
#             # 20.0 % obj: @:Genre. Cardinality: {2}
#    schema:ISBN  xsd:string  ;                                  # 100.0 %
#    schema:publisher  @:Organization  ;                         # 100.0 %
#    schema:translatedInto  xsd:string  ?
#             # 60.0 % obj: xsd:string. Cardinality: {1}
# }
#
#
# :Organization
# {
#    rdf:type  [schema:Organization]  ;                          # 100.0 %
#    schema:name  xsd:string                                     # 100.0 %
# }

# %%
from shexer.shaper import Shaper
from shexer.consts import TURTLE_ITER

rdf_local_path = "/content/miw_websem2425/lab_sessions/books_data.ttl"

namespaces_dict = {"http://www.w3.org/1999/02/22-rdf-syntax-ns#": "rdf",
                   "http://example.org/": "ex",
                   "http://www.w3.org/2001/XMLSchema#": "xsd",
                   "http://schema.org/" : "schema",
                   "http://xmlns.com/foaf/0.1/" : "foaf",
                   "http://purl.org/dc/terms/" : "dcterms"
                   }

# Mismo caso que el anterior, pero ahora sólo se incluirán en el resultado características observadas en al menos
# el 80% de los nodos usados como ejemplo para extraer una shape. Esto afecta a las contraints con una cardinalidad
# mñinima de cero, como la cardinalidad opcional (?) o el cierre de Kleene (*).

shaper = Shaper(graph_file_input=rdf_local_path,
                input_format=TURTLE_ITER,
                all_classes_mode=True,
                disable_comments=False,
                namespaces_dict=namespaces_dict)

result = shaper.shex_graph(string_output=True,
                           acceptance_threshold=0.8) # Esta cifra es un ratio que me indica la frecuencia mínimma
                                                     # con la que se debe observar algo para incluir ese algo en el resultado
                                                     # con una cardinalidad mínima de cero.

print(result)
# Out:
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX ex: <http://example.org/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX : <http://weso.es/shapes/>
#
# :Person
# {
#    rdf:type  [schema:Person]  ;                                # 100.0 %
#    foaf:name  xsd:string  ;                                    # 100.0 %
#    schema:birthDate  xsd:date  ;                               # 100.0 %
#    schema:nationality  xsd:string                              # 100.0 %
# }
#
#
# :Genre
# {
#    rdf:type  [schema:Genre]  ;                                 # 100.0 %
#    schema:name  xsd:string                                     # 100.0 %
# }
#
#
# :Book
# {
#    rdf:type  [schema:Book]  ;                                  # 100.0 %
#    dcterms:title  xsd:string  ;                                # 100.0 %
#    schema:author  @:Person  ;                                  # 100.0 %
#    schema:datePublished  xsd:date  ;                           # 100.0 %
#    schema:genre  @:Genre  +;                                   # 100.0 %
#             # 80.0 % obj: @:Genre. Cardinality: {1}
#    schema:ISBN  xsd:string  ;                                  # 100.0 %
#    schema:publisher  @:Organization                            # 100.0 %
# }
#
#
# :Organization
# {
#    rdf:type  [schema:Organization]  ;                          # 100.0 %
#    schema:name  xsd:string                                     # 100.0 %
# }

# %%
from shexer.shaper import Shaper
from shexer.consts import TURTLE_ITER

rdf_local_path = "/content/miw_websem2425/lab_sessions/books_data.ttl"

namespaces_dict = {"http://www.w3.org/1999/02/22-rdf-syntax-ns#": "rdf",
                   "http://example.org/": "ex",
                   "http://www.w3.org/2001/XMLSchema#": "xsd",
                   "http://schema.org/" : "schema",
                   "http://xmlns.com/foaf/0.1/" : "foaf",
                   "http://purl.org/dc/terms/" : "dcterms"
                   }

# Mismo caso que el anterior, pero sin ratio de aceptación (por defecto, el ratio es cero). Además, ya no pedimos
# sacar una shape para cada clase, sino sólo para un grupo de clases.

shaper = Shaper(graph_file_input=rdf_local_path,
                input_format=TURTLE_ITER,
                target_classes=["schema:Book", "schema:Genre"],
                disable_comments=False,
                namespaces_dict=namespaces_dict)

result = shaper.shex_graph(string_output=True)

print(result)
# Out:
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX ex: <http://example.org/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX : <http://weso.es/shapes/>
#
# :Book
# {
#    rdf:type  [schema:Book]  ;                                  # 100.0 %
#    dcterms:title  xsd:string  ;                                # 100.0 %
#    schema:author  IRI  ;                                       # 100.0 %
#    schema:datePublished  xsd:date  ;                           # 100.0 %
#    schema:genre  @:Genre  +;                                   # 100.0 %
#             # 80.0 % obj: @:Genre. Cardinality: {1}
#             # 20.0 % obj: @:Genre. Cardinality: {2}
#    schema:ISBN  xsd:string  ;                                  # 100.0 %
#    schema:publisher  IRI  ;                                    # 100.0 %
#    schema:translatedInto  xsd:string  ?
#             # 60.0 % obj: xsd:string. Cardinality: {1}
# }
#
#
# :Genre
# {
#    rdf:type  [schema:Genre]  ;                                 # 100.0 %
#    schema:name  xsd:string                                     # 100.0 %
# }

# %%
from shexer.shaper import Shaper
from shexer.consts import TURTLE_ITER



namespaces_dict = {"http://www.w3.org/1999/02/22-rdf-syntax-ns#": "rdf",
                   "http://example.org/": "ex",
                   "http://www.w3.org/2001/XMLSchema#": "xsd",
                   "http://schema.org/" : "schema",
                   "http://xmlns.com/foaf/0.1/" : "foaf",
                   "http://purl.org/dc/terms/" : "dcterms",
                   "http://dbpedia.org/ontology/" : "dbo",
                   "http://dbpedia.org/resource/" : "dbr",
                   "http://dbpedia.org/property/" : "dbp",
                   "http://www.w3.org/2000/01/rdf-schema#" : "rdfs"
                   }

# En esta ocasión se mina contenido del endpoint de DBpedia. Sólo se busca sacar la shape de libro,
# sólo se usaran 10 instancias de ejemplo de libro y, tomando como raíz esas 10 instancias, sólo se traerá
# contenido del grafo a un nivel de distancia de 2 de los nodos raíz.

# PRECAUCIÓN AL EXTRAER SHAPES DE ENDPOINTS! Este proceso puede requerir hacer muchas ocnsultas SPARQL, y esto podría
# hacer que el proceso tarde mucho o, si se están usando endpoints públicos de terceros, que el proceso caiga debido a timeouts
# o baneos de IP por uso masivo del endpoint.

shaper = Shaper(target_classes=["http://dbpedia.org/ontology/Book"],
                url_endpoint="https://dbpedia.org/sparql",
                namespaces_dict=namespaces_dict,
                instances_cap=10,  # Sólamente se buscarán 10 ejemplos de instancia para extraer una shape.
                depth_for_building_subgraph=2,  # Partimos de als entidades de ejemplo y exploramos el grafo alrededor hasta esta distancia.
                track_classes_for_entities_at_last_depth_level=True) # Nos saltaremos la restricción de nivel de profundidad 2 SÓLO para tripletas de tipado

                # Aunque en el shape map sólo tengamos una clase objetivo, generaremos clases para el resto de elementos que hayan
                                        # aparecido al traer parte del grafo consumiendo en endpoint.

str_result = shaper.shex_graph(string_output=True,
                               acceptance_threshold=0.2) # Excluimos cosas que no se observen al menos el 20% de las veces



print(result)
# Out:
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX ex: <http://example.org/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX : <http://weso.es/shapes/>
#
# :Book
# {
#    rdf:type  [dbo:Book]  ;                                     # 100.0 %
#    rdfs:label  xsd:string  +;                                  # 100.0 %
#             # 60.0 % obj: xsd:string. Cardinality: {1}
#             # 10.0 % obj: xsd:string. Cardinality: {16}
#             # 10.0 % obj: xsd:string. Cardinality: {3}
#             # 10.0 % obj: xsd:string. Cardinality: {5}
#             # 10.0 % obj: xsd:string. Cardinality: {6}
#    dbo:wikiPageID  xsd:integer  ;                              # 100.0 %
#    dbo:wikiPageRevisionID  xsd:integer  ;                      # 100.0 %
#    dbo:wikiPageWikiLink  IRI  +;                               # 100.0 %
#             # 10.0 % obj: IRI. Cardinality: {67}
#             # 10.0 % obj: IRI. Cardinality: {3}
#             # 10.0 % obj: IRI. Cardinality: {51}
#             # 10.0 % obj: IRI. Cardinality: {23}
#             # 10.0 % obj: IRI. Cardinality: {29}
#             # 10.0 % obj: IRI. Cardinality: {1}
#             # 10.0 % obj: IRI. Cardinality: {2}
#             # 10.0 % obj: IRI. Cardinality: {41}
#             # 10.0 % obj: IRI. Cardinality: {14}
#             # 10.0 % obj: IRI. Cardinality: {11}
#    <http://www.w3.org/2002/07/owl#sameAs>  IRI  +;             # 100.0 %
#             # 20.0 % obj: IRI. Cardinality: {6}
#             # 20.0 % obj: IRI. Cardinality: {3}
#             # 20.0 % obj: IRI. Cardinality: {7}
#             # 10.0 % obj: IRI. Cardinality: {30}
#             # 10.0 % obj: IRI. Cardinality: {8}
#             # 10.0 % obj: IRI. Cardinality: {11}
#             # 10.0 % obj: IRI. Cardinality: {4}
#    dbp:wikiPageUsesTemplate  IRI  +;                           # 100.0 %
#             # 20.0 % obj: IRI. Cardinality: {11}
#             # 10.0 % obj: IRI. Cardinality: {16}
#             # 10.0 % obj: IRI. Cardinality: {12}
#             # 10.0 % obj: IRI. Cardinality: {10}
#             # 10.0 % obj: IRI. Cardinality: {6}
#             # 10.0 % obj: IRI. Cardinality: {9}
#             # 10.0 % obj: IRI. Cardinality: {3}
#             # 10.0 % obj: IRI. Cardinality: {7}
#             # 10.0 % obj: IRI. Cardinality: {8}
#    <http://purl.org/linguistics/gold/hypernym>  IRI  ;          # 100.0 %
#    <http://www.w3.org/ns/prov#wasDerivedFrom>  IRI  ;          # 100.0 %
#    dbo:wikiPageLength  xsd:integer  ;                          # 100.0 %
#    foaf:isPrimaryTopicOf  IRI  ;                               # 100.0 %
#    rdfs:comment  xsd:string  *;
#             # 90.0 % obj: xsd:string. Cardinality: +
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # 10.0 % obj: xsd:string. Cardinality: {16}
#             # 10.0 % obj: xsd:string. Cardinality: {3}
#             # 10.0 % obj: xsd:string. Cardinality: {5}
#             # 10.0 % obj: xsd:string. Cardinality: {6}
#    foaf:depiction  IRI  *;
#             # 90.0 % obj: IRI. Cardinality: +
#             # 70.0 % obj: IRI. Cardinality: {1}
#             # 20.0 % obj: IRI. Cardinality: {3}
#    dcterms:subject  IRI  *;
#             # 90.0 % obj: IRI. Cardinality: +
#             # 20.0 % obj: IRI. Cardinality: {1}
#             # 20.0 % obj: IRI. Cardinality: {9}
#             # 20.0 % obj: IRI. Cardinality: {3}
#             # 10.0 % obj: IRI. Cardinality: {5}
#             # 10.0 % obj: IRI. Cardinality: {4}
#             # 10.0 % obj: IRI. Cardinality: {7}
#    dbo:thumbnail  IRI  ?;
#             # 90.0 % obj: IRI. Cardinality: {1}
#    dbo:abstract  xsd:string  *;
#             # 90.0 % obj: xsd:string. Cardinality: +
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # 10.0 % obj: xsd:string. Cardinality: {16}
#             # 10.0 % obj: xsd:string. Cardinality: {3}
#             # 10.0 % obj: xsd:string. Cardinality: {5}
#             # 10.0 % obj: xsd:string. Cardinality: {6}
#    rdf:type  [<http://www.w3.org/2002/07/owl#Thing>]  ?;
#             # 80.0 % obj: <http://www.w3.org/2002/07/owl#Thing>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Abstraction100002137>]  ?;
#             # 70.0 % obj: <http://dbpedia.org/class/yago/Abstraction100002137>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatCalciumCompounds>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/WikicatCalciumCompounds>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Cognition100023271>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Cognition100023271>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Compound105870180>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Compound105870180>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Concept105835747>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Concept105835747>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Content105809192>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Content105809192>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Idea105833840>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Idea105833840>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/PsychologicalFeature100023100>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/PsychologicalFeature100023100>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Whole105869584>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Whole105869584>. Cardinality: {1}
#    rdf:type  [<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#ChemicalObject>]  ?;
#             # 40.0 % obj: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#ChemicalObject>. Cardinality: {1}
#    rdf:type  [dbo:ChemicalSubstance]  ?;
#             # 40.0 % obj: dbo:ChemicalSubstance. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/PhysicalEntity100001930>]  ?;
#             # 40.0 % obj: <http://dbpedia.org/class/yago/PhysicalEntity100001930>. Cardinality: {1}
#    dbo:wikiPageExternalLink  IRI  *;
#             # 40.0 % obj: IRI. Cardinality: +
#             # 20.0 % obj: IRI. Cardinality: {1}
#             # 10.0 % obj: IRI. Cardinality: {6}
#             # 10.0 % obj: IRI. Cardinality: {5}
#    foaf:name  xsd:string  *;
#             # 40.0 % obj: xsd:string. Cardinality: +
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    rdf:type  [<http://www.wikidata.org/entity/Q8386>]  ?;
#             # 30.0 % obj: <http://www.wikidata.org/entity/Q8386>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Chemical114806838>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Chemical114806838>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Compound114818238>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Compound114818238>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Material114580897>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Material114580897>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Matter100020827>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Matter100020827>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Part113809207>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Part113809207>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Relation100031921>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Relation100031921>. Cardinality: {1}
#    rdf:type  [dbo:Drug]  ?;
#             # 30.0 % obj: dbo:Drug. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Salt115010703>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Salt115010703>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Substance100019613>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Substance100019613>. Cardinality: {1}
#    rdf:type  [<http://umbel.org/umbel/rc/ChemicalSubstanceType>]  ?;
#             # 30.0 % obj: <http://umbel.org/umbel/rc/ChemicalSubstanceType>. Cardinality: {1}
#    rdf:type  [schema:CreativeWork]  ?;
#             # 30.0 % obj: schema:CreativeWork. Cardinality: {1}
#    rdf:type  [dbo:Work]  ?;
#             # 30.0 % obj: dbo:Work. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q386724>]  ?;
#             # 30.0 % obj: <http://www.wikidata.org/entity/Q386724>. Cardinality: {1}
#    dbp:atcSuffix  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:atcPrefix  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:c  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:casNumber  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:chemspiderid  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:h  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:iupacName  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:o  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:pubchem  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:smiles  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:stdinchi  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:stdinchikey  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:ca  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:casNumber  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbo:fdaUniiCode  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbo:pubchem  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:verifiedfields  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:verifiedrevid  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:caption  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbo:publisher  IRI  *;
#             # 30.0 % obj: IRI. Cardinality: +
#             # 20.0 % obj: IRI. Cardinality: {1}
#             # 10.0 % obj: IRI. Cardinality: {2}
#    dbp:name  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    rdf:type  [<http://umbel.org/umbel/rc/DrugProduct>]  ?;
#             # 20.0 % obj: <http://umbel.org/umbel/rc/DrugProduct>. Cardinality: {1}
#    rdf:type  [<http://purl.org/ontology/bibo/Book>]  ?;
#             # 20.0 % obj: <http://purl.org/ontology/bibo/Book>. Cardinality: {1}
#    rdf:type  [schema:Book]  ?;
#             # 20.0 % obj: schema:Book. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q234460>]  ?;
#             # 20.0 % obj: <http://www.wikidata.org/entity/Q234460>. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q571>]  ?;
#             # 20.0 % obj: <http://www.wikidata.org/entity/Q571>. Cardinality: {1}
#    rdf:type  [dbo:WrittenWork]  ?;
#             # 20.0 % obj: dbo:WrittenWork. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Communication100033020>]  ?;
#             # 20.0 % obj: <http://dbpedia.org/class/yago/Communication100033020>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Writing106362953>]  ?;
#             # 20.0 % obj: <http://dbpedia.org/class/yago/Writing106362953>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WrittenCommunication106349220>]  ?;
#             # 20.0 % obj: <http://dbpedia.org/class/yago/WrittenCommunication106349220>. Cardinality: {1}
#    dbp:drugbank  xsd:string  ?;
#             # 20.0 % obj: xsd:string. Cardinality: {1}
#    dbp:unii  xsd:string  ?;
#             # 20.0 % obj: xsd:string. Cardinality: {1}
#    dbo:drugbank  xsd:string  ?;
#             # 20.0 % obj: xsd:string. Cardinality: {1}
#    dbp:watchedfields  xsd:string  ?;
#             # 20.0 % obj: xsd:string. Cardinality: {1}
#    dbp:genre  IRI  *;
#             # 20.0 % obj: IRI. Cardinality: +
#             # 10.0 % obj: IRI. Cardinality: {2}
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:publisher  IRI  *;
#             # 20.0 % obj: IRI. Cardinality: +
#             # 10.0 % obj: IRI. Cardinality: {1}
#             # 10.0 % obj: IRI. Cardinality: {2}
#    <http://purl.org/dc/elements/1.1/publisher>  xsd:string  *;
#             # 20.0 % obj: xsd:string. Cardinality: +
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbp:author  IRI  ?;
#             # 20.0 % obj: IRI. Cardinality: {1}
#    dbp:mediaType  xsd:string  ?;
#             # 20.0 % obj: xsd:string. Cardinality: {1}
#    dbp:pages  xsd:integer  ?;
#             # 20.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:releaseDate  xsd:integer  ?;
#             # 20.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:numberOfPages  xsd:integer  ?;
#             # 20.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:author  IRI  ?;
#             # 20.0 % obj: IRI. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatWorldHealthOrganizationEssentialMedicines>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatWorldHealthOrganizationEssentialMedicines>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatSaltsAndEstersOfCarboxylicAcids>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatSaltsAndEstersOfCarboxylicAcids>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Discipline105996646>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Discipline105996646>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/KnowledgeDomain105999266>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/KnowledgeDomain105999266>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/LifeScience106037298>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/LifeScience106037298>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/MedicalScience106045562>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/MedicalScience106045562>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Medicine106043075>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Medicine106043075>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Mineral114662574>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Mineral114662574>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/NaturalScience106000400>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/NaturalScience106000400>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Science105999797>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Science105999797>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatDietaryMinerals>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatDietaryMinerals>. Cardinality: {1}
#    rdf:type  [dbo:Software]  ?;
#             # 10.0 % obj: dbo:Software. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q7397>]  ?;
#             # 10.0 % obj: <http://www.wikidata.org/entity/Q7397>. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q7889>]  ?;
#             # 10.0 % obj: <http://www.wikidata.org/entity/Q7889>. Cardinality: {1}
#    rdf:type  [dbo:VideoGame]  ?;
#             # 10.0 % obj: dbo:VideoGame. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Artifact100021939>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Artifact100021939>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Book106410904>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Book106410904>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Creation103129123>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Creation103129123>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Object100002684>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Object100002684>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Product104007894>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Product104007894>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Publication106589574>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Publication106589574>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Work104599396>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Work104599396>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Whole100003553>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Whole100003553>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatBritishNovellas>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatBritishNovellas>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatBritishNovels>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatBritishNovels>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatNovelsByCliveBarker>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatNovelsByCliveBarker>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatShortStoryCollectionsByCliveBarker>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatShortStoryCollectionsByCliveBarker>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Collection107951464>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Collection107951464>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Fiction106367107>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Fiction106367107>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Group100031264>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Group100031264>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/LiteraryComposition106364329>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/LiteraryComposition106364329>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Novel106367879>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Novel106367879>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Novelette106368962>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Novelette106368962>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatHorrorNovels>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatHorrorNovels>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Wikicat1980sFantasyNovels>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Wikicat1980sFantasyNovels>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Wikicat1988Novels>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Wikicat1988Novels>. Cardinality: {1}
#    rdf:type  [<http://umbel.org/umbel/rc/Book_CW>]  ?;
#             # 10.0 % obj: <http://umbel.org/umbel/rc/Book_CW>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatSalts>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatSalts>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatBuddhistTexts>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatBuddhistTexts>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatConfucianTexts>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatConfucianTexts>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Matter106365467>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Matter106365467>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Text106387980>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Text106387980>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatTaoistTexts>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatTaoistTexts>. Cardinality: {1}
#    rdf:type  [dbo:Place]  ?;
#             # 10.0 % obj: dbo:Place. Cardinality: {1}
#    rdf:type  [dbo:Location]  ?;
#             # 10.0 % obj: dbo:Location. Cardinality: {1}
#    rdf:type  [schema:LandmarksOrHistoricalBuildings]  ?;
#             # 10.0 % obj: schema:LandmarksOrHistoricalBuildings. Cardinality: {1}
#    rdf:type  [schema:Place]  ?;
#             # 10.0 % obj: schema:Place. Cardinality: {1}
#    rdf:type  [<http://www.w3.org/2003/01/geo/wgs84_pos#SpatialThing>]  ?;
#             # 10.0 % obj: <http://www.w3.org/2003/01/geo/wgs84_pos#SpatialThing>. Cardinality: {1}
#    rdf:type  [dbo:HistoricPlace]  ?;
#             # 10.0 % obj: dbo:HistoricPlace. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q11173>]  ?;
#             # 10.0 % obj: <http://www.wikidata.org/entity/Q11173>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatCitrates>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatCitrates>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Citrate114604184>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Citrate114604184>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Ester114850483>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Ester114850483>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/OrganicCompound114727670>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/OrganicCompound114727670>. Cardinality: {1}
#    rdf:type  [dbo:ChemicalCompound]  ?;
#             # 10.0 % obj: dbo:ChemicalCompound. Cardinality: {1}
#    dbp:solubility  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:c  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:chebi  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:chembl  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:image  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:kegg  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:meltingPoint  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:pregnancyUs  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:routesOfAdministration  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:unii  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:dailymedid  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:licenceUs  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:meltingNotes  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:pregnancyUsComment  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbo:chEBI  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:chEMBL  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:kegg  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:developer  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:extraColumn  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:fam  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:headline  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:length  xsd:integer  *;
#             # 10.0 % obj: xsd:integer. Cardinality: {17}
#    dbp:modes  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:note  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {16}
#    dbp:platforms  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:platforms  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbp:publisher  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbp:released  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {3}
#    dbp:title  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {19}
#    dbp:totalLength  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:releaseDate  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbo:computingPlatform  IRI  *;
#             # 10.0 % obj: IRI. Cardinality: {3}
#    dbo:genre  IRI  *;
#             # 10.0 % obj: IRI. Cardinality: {2}
#    rdfs:seeAlso  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:country  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:country  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:coverArtist  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:coverArtist  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:isbn  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:isbnNote  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:language  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:language  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:origLangCode  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:titleOrig  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:translator  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbo:isbn  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbo:country  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbo:language  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbo:mediaType  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbo:coverArtist  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbo:literaryGenre  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbo:wikiPageRedirects  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:1a  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:1y  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:2a  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbp:2pp  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:2y  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:l  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:p  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbp:s  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:t  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:w  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    <http://www.w3.org/2003/01/geo/wgs84_pos#lat>  xsd:float  ?;
#             # 10.0 % obj: xsd:float. Cardinality: {1}
#    <http://www.w3.org/2003/01/geo/wgs84_pos#long>  xsd:float  ?;
#             # 10.0 % obj: xsd:float. Cardinality: {1}
#    dbo:location  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:added  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:architect  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:architecture  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:builder  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:location  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:locmapin  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:mapCaption  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:nocat  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:nrhpType  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:refnum  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    <http://www.georss.org/georss/point>  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbo:area  xsd:float  ?;
#             # 10.0 % obj: xsd:float. Cardinality: {1}
#    dbo:nrhpReferenceNumber  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:yearOfConstruction  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:architect  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    <http://www.w3.org/2003/01/geo/wgs84_pos#geometry>  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:imagefile  xsd:string  ?
#             # 10.0 % obj: xsd:string. Cardinality: {1}
# }

# %%
from shexer.shaper import Shaper
from shexer.consts import TURTLE_ITER



namespaces_dict = {"http://www.w3.org/1999/02/22-rdf-syntax-ns#": "rdf",
                   "http://example.org/": "ex",
                   "http://www.w3.org/2001/XMLSchema#": "xsd",
                   "http://schema.org/" : "schema",
                   "http://xmlns.com/foaf/0.1/" : "foaf",
                   "http://purl.org/dc/terms/" : "dcterms",
                   "http://dbpedia.org/ontology/" : "dbo",
                   "http://dbpedia.org/resource/" : "dbr",
                   "http://dbpedia.org/property/" : "dbp",
                   "http://www.w3.org/2000/01/rdf-schema#" : "rdfs"
                   }

# Lo mismo, pero usando un shape map en lugar de listas de clases objetivo.

# No usaré una expresión FOCUS estandar, porque podría arrojarme una consulta que tarde demasiado. Usaré una consulta SPARQL.
# Esto no forma parte del estandar de los shape maps, aunque hubo proyecto de que suese así.
# Si quieres utilizar consultas SPARQL para seleccionar nodos, sigue el patrón del ejemplo
# SPARQL' ... AQUÍ TU CONSULTA SPARQL...'@<Uri de la shape>

shape_map_raw = "SPARQL'select ?s where {?s a <http://dbpedia.org/ontology/Book>} LIMIT 100'@:Book"

shaper = Shaper(url_endpoint="https://dbpedia.org/sparql",
                shape_map_raw=shape_map_raw,
                namespaces_dict=namespaces_dict,
                instances_cap=10,
                depth_for_building_subgraph=1,
                track_classes_for_entities_at_last_depth_level=True)



str_result = shaper.shex_graph(string_output=True,
                               acceptance_threshold=0.2)



print(result)
# Out:
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX ex: <http://example.org/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX : <http://weso.es/shapes/>
#
# :Book
# {
#    rdf:type  [dbo:Book]  ;                                     # 100.0 %
#    rdfs:label  xsd:string  +;                                  # 100.0 %
#             # 60.0 % obj: xsd:string. Cardinality: {1}
#             # 10.0 % obj: xsd:string. Cardinality: {16}
#             # 10.0 % obj: xsd:string. Cardinality: {3}
#             # 10.0 % obj: xsd:string. Cardinality: {5}
#             # 10.0 % obj: xsd:string. Cardinality: {6}
#    dbo:wikiPageID  xsd:integer  ;                              # 100.0 %
#    dbo:wikiPageRevisionID  xsd:integer  ;                      # 100.0 %
#    dbo:wikiPageWikiLink  IRI  +;                               # 100.0 %
#             # 10.0 % obj: IRI. Cardinality: {67}
#             # 10.0 % obj: IRI. Cardinality: {3}
#             # 10.0 % obj: IRI. Cardinality: {51}
#             # 10.0 % obj: IRI. Cardinality: {23}
#             # 10.0 % obj: IRI. Cardinality: {29}
#             # 10.0 % obj: IRI. Cardinality: {1}
#             # 10.0 % obj: IRI. Cardinality: {2}
#             # 10.0 % obj: IRI. Cardinality: {41}
#             # 10.0 % obj: IRI. Cardinality: {14}
#             # 10.0 % obj: IRI. Cardinality: {11}
#    <http://www.w3.org/2002/07/owl#sameAs>  IRI  +;             # 100.0 %
#             # 20.0 % obj: IRI. Cardinality: {6}
#             # 20.0 % obj: IRI. Cardinality: {3}
#             # 20.0 % obj: IRI. Cardinality: {7}
#             # 10.0 % obj: IRI. Cardinality: {30}
#             # 10.0 % obj: IRI. Cardinality: {8}
#             # 10.0 % obj: IRI. Cardinality: {11}
#             # 10.0 % obj: IRI. Cardinality: {4}
#    dbp:wikiPageUsesTemplate  IRI  +;                           # 100.0 %
#             # 20.0 % obj: IRI. Cardinality: {11}
#             # 10.0 % obj: IRI. Cardinality: {16}
#             # 10.0 % obj: IRI. Cardinality: {12}
#             # 10.0 % obj: IRI. Cardinality: {10}
#             # 10.0 % obj: IRI. Cardinality: {6}
#             # 10.0 % obj: IRI. Cardinality: {9}
#             # 10.0 % obj: IRI. Cardinality: {3}
#             # 10.0 % obj: IRI. Cardinality: {7}
#             # 10.0 % obj: IRI. Cardinality: {8}
#    <http://purl.org/linguistics/gold/hypernym>  IRI  ;          # 100.0 %
#    <http://www.w3.org/ns/prov#wasDerivedFrom>  IRI  ;          # 100.0 %
#    dbo:wikiPageLength  xsd:integer  ;                          # 100.0 %
#    foaf:isPrimaryTopicOf  IRI  ;                               # 100.0 %
#    rdfs:comment  xsd:string  *;
#             # 90.0 % obj: xsd:string. Cardinality: +
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # 10.0 % obj: xsd:string. Cardinality: {16}
#             # 10.0 % obj: xsd:string. Cardinality: {3}
#             # 10.0 % obj: xsd:string. Cardinality: {5}
#             # 10.0 % obj: xsd:string. Cardinality: {6}
#    foaf:depiction  IRI  *;
#             # 90.0 % obj: IRI. Cardinality: +
#             # 70.0 % obj: IRI. Cardinality: {1}
#             # 20.0 % obj: IRI. Cardinality: {3}
#    dcterms:subject  IRI  *;
#             # 90.0 % obj: IRI. Cardinality: +
#             # 20.0 % obj: IRI. Cardinality: {1}
#             # 20.0 % obj: IRI. Cardinality: {9}
#             # 20.0 % obj: IRI. Cardinality: {3}
#             # 10.0 % obj: IRI. Cardinality: {5}
#             # 10.0 % obj: IRI. Cardinality: {4}
#             # 10.0 % obj: IRI. Cardinality: {7}
#    dbo:thumbnail  IRI  ?;
#             # 90.0 % obj: IRI. Cardinality: {1}
#    dbo:abstract  xsd:string  *;
#             # 90.0 % obj: xsd:string. Cardinality: +
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # 10.0 % obj: xsd:string. Cardinality: {16}
#             # 10.0 % obj: xsd:string. Cardinality: {3}
#             # 10.0 % obj: xsd:string. Cardinality: {5}
#             # 10.0 % obj: xsd:string. Cardinality: {6}
#    rdf:type  [<http://www.w3.org/2002/07/owl#Thing>]  ?;
#             # 80.0 % obj: <http://www.w3.org/2002/07/owl#Thing>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Abstraction100002137>]  ?;
#             # 70.0 % obj: <http://dbpedia.org/class/yago/Abstraction100002137>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatCalciumCompounds>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/WikicatCalciumCompounds>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Cognition100023271>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Cognition100023271>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Compound105870180>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Compound105870180>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Concept105835747>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Concept105835747>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Content105809192>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Content105809192>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Idea105833840>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Idea105833840>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/PsychologicalFeature100023100>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/PsychologicalFeature100023100>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Whole105869584>]  ?;
#             # 50.0 % obj: <http://dbpedia.org/class/yago/Whole105869584>. Cardinality: {1}
#    rdf:type  [<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#ChemicalObject>]  ?;
#             # 40.0 % obj: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#ChemicalObject>. Cardinality: {1}
#    rdf:type  [dbo:ChemicalSubstance]  ?;
#             # 40.0 % obj: dbo:ChemicalSubstance. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/PhysicalEntity100001930>]  ?;
#             # 40.0 % obj: <http://dbpedia.org/class/yago/PhysicalEntity100001930>. Cardinality: {1}
#    dbo:wikiPageExternalLink  IRI  *;
#             # 40.0 % obj: IRI. Cardinality: +
#             # 20.0 % obj: IRI. Cardinality: {1}
#             # 10.0 % obj: IRI. Cardinality: {6}
#             # 10.0 % obj: IRI. Cardinality: {5}
#    foaf:name  xsd:string  *;
#             # 40.0 % obj: xsd:string. Cardinality: +
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    rdf:type  [<http://www.wikidata.org/entity/Q8386>]  ?;
#             # 30.0 % obj: <http://www.wikidata.org/entity/Q8386>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Chemical114806838>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Chemical114806838>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Compound114818238>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Compound114818238>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Material114580897>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Material114580897>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Matter100020827>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Matter100020827>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Part113809207>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Part113809207>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Relation100031921>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Relation100031921>. Cardinality: {1}
#    rdf:type  [dbo:Drug]  ?;
#             # 30.0 % obj: dbo:Drug. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Salt115010703>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Salt115010703>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Substance100019613>]  ?;
#             # 30.0 % obj: <http://dbpedia.org/class/yago/Substance100019613>. Cardinality: {1}
#    rdf:type  [<http://umbel.org/umbel/rc/ChemicalSubstanceType>]  ?;
#             # 30.0 % obj: <http://umbel.org/umbel/rc/ChemicalSubstanceType>. Cardinality: {1}
#    rdf:type  [schema:CreativeWork]  ?;
#             # 30.0 % obj: schema:CreativeWork. Cardinality: {1}
#    rdf:type  [dbo:Work]  ?;
#             # 30.0 % obj: dbo:Work. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q386724>]  ?;
#             # 30.0 % obj: <http://www.wikidata.org/entity/Q386724>. Cardinality: {1}
#    dbp:atcSuffix  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:atcPrefix  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:c  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:casNumber  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:chemspiderid  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:h  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:iupacName  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:o  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:pubchem  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:smiles  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:stdinchi  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:stdinchikey  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:ca  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:casNumber  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbo:fdaUniiCode  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbo:pubchem  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:verifiedfields  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbp:verifiedrevid  xsd:integer  ?;
#             # 30.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:caption  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    dbo:publisher  IRI  *;
#             # 30.0 % obj: IRI. Cardinality: +
#             # 20.0 % obj: IRI. Cardinality: {1}
#             # 10.0 % obj: IRI. Cardinality: {2}
#    dbp:name  xsd:string  ?;
#             # 30.0 % obj: xsd:string. Cardinality: {1}
#    rdf:type  [<http://umbel.org/umbel/rc/DrugProduct>]  ?;
#             # 20.0 % obj: <http://umbel.org/umbel/rc/DrugProduct>. Cardinality: {1}
#    rdf:type  [<http://purl.org/ontology/bibo/Book>]  ?;
#             # 20.0 % obj: <http://purl.org/ontology/bibo/Book>. Cardinality: {1}
#    rdf:type  [schema:Book]  ?;
#             # 20.0 % obj: schema:Book. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q234460>]  ?;
#             # 20.0 % obj: <http://www.wikidata.org/entity/Q234460>. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q571>]  ?;
#             # 20.0 % obj: <http://www.wikidata.org/entity/Q571>. Cardinality: {1}
#    rdf:type  [dbo:WrittenWork]  ?;
#             # 20.0 % obj: dbo:WrittenWork. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Communication100033020>]  ?;
#             # 20.0 % obj: <http://dbpedia.org/class/yago/Communication100033020>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Writing106362953>]  ?;
#             # 20.0 % obj: <http://dbpedia.org/class/yago/Writing106362953>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WrittenCommunication106349220>]  ?;
#             # 20.0 % obj: <http://dbpedia.org/class/yago/WrittenCommunication106349220>. Cardinality: {1}
#    dbp:drugbank  xsd:string  ?;
#             # 20.0 % obj: xsd:string. Cardinality: {1}
#    dbp:unii  xsd:string  ?;
#             # 20.0 % obj: xsd:string. Cardinality: {1}
#    dbo:drugbank  xsd:string  ?;
#             # 20.0 % obj: xsd:string. Cardinality: {1}
#    dbp:watchedfields  xsd:string  ?;
#             # 20.0 % obj: xsd:string. Cardinality: {1}
#    dbp:genre  IRI  *;
#             # 20.0 % obj: IRI. Cardinality: +
#             # 10.0 % obj: IRI. Cardinality: {2}
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:publisher  IRI  *;
#             # 20.0 % obj: IRI. Cardinality: +
#             # 10.0 % obj: IRI. Cardinality: {1}
#             # 10.0 % obj: IRI. Cardinality: {2}
#    <http://purl.org/dc/elements/1.1/publisher>  xsd:string  *;
#             # 20.0 % obj: xsd:string. Cardinality: +
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbp:author  IRI  ?;
#             # 20.0 % obj: IRI. Cardinality: {1}
#    dbp:mediaType  xsd:string  ?;
#             # 20.0 % obj: xsd:string. Cardinality: {1}
#    dbp:pages  xsd:integer  ?;
#             # 20.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:releaseDate  xsd:integer  ?;
#             # 20.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:numberOfPages  xsd:integer  ?;
#             # 20.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:author  IRI  ?;
#             # 20.0 % obj: IRI. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatWorldHealthOrganizationEssentialMedicines>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatWorldHealthOrganizationEssentialMedicines>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatSaltsAndEstersOfCarboxylicAcids>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatSaltsAndEstersOfCarboxylicAcids>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Discipline105996646>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Discipline105996646>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/KnowledgeDomain105999266>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/KnowledgeDomain105999266>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/LifeScience106037298>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/LifeScience106037298>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/MedicalScience106045562>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/MedicalScience106045562>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Medicine106043075>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Medicine106043075>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Mineral114662574>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Mineral114662574>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/NaturalScience106000400>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/NaturalScience106000400>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Science105999797>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Science105999797>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatDietaryMinerals>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatDietaryMinerals>. Cardinality: {1}
#    rdf:type  [dbo:Software]  ?;
#             # 10.0 % obj: dbo:Software. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q7397>]  ?;
#             # 10.0 % obj: <http://www.wikidata.org/entity/Q7397>. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q7889>]  ?;
#             # 10.0 % obj: <http://www.wikidata.org/entity/Q7889>. Cardinality: {1}
#    rdf:type  [dbo:VideoGame]  ?;
#             # 10.0 % obj: dbo:VideoGame. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Artifact100021939>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Artifact100021939>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Book106410904>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Book106410904>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Creation103129123>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Creation103129123>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Object100002684>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Object100002684>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Product104007894>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Product104007894>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Publication106589574>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Publication106589574>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Work104599396>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Work104599396>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Whole100003553>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Whole100003553>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatBritishNovellas>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatBritishNovellas>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatBritishNovels>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatBritishNovels>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatNovelsByCliveBarker>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatNovelsByCliveBarker>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatShortStoryCollectionsByCliveBarker>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatShortStoryCollectionsByCliveBarker>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Collection107951464>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Collection107951464>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Fiction106367107>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Fiction106367107>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Group100031264>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Group100031264>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/LiteraryComposition106364329>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/LiteraryComposition106364329>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Novel106367879>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Novel106367879>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Novelette106368962>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Novelette106368962>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatHorrorNovels>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatHorrorNovels>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Wikicat1980sFantasyNovels>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Wikicat1980sFantasyNovels>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Wikicat1988Novels>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Wikicat1988Novels>. Cardinality: {1}
#    rdf:type  [<http://umbel.org/umbel/rc/Book_CW>]  ?;
#             # 10.0 % obj: <http://umbel.org/umbel/rc/Book_CW>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatSalts>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatSalts>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatBuddhistTexts>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatBuddhistTexts>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatConfucianTexts>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatConfucianTexts>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Matter106365467>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Matter106365467>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Text106387980>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Text106387980>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatTaoistTexts>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatTaoistTexts>. Cardinality: {1}
#    rdf:type  [dbo:Place]  ?;
#             # 10.0 % obj: dbo:Place. Cardinality: {1}
#    rdf:type  [dbo:Location]  ?;
#             # 10.0 % obj: dbo:Location. Cardinality: {1}
#    rdf:type  [schema:LandmarksOrHistoricalBuildings]  ?;
#             # 10.0 % obj: schema:LandmarksOrHistoricalBuildings. Cardinality: {1}
#    rdf:type  [schema:Place]  ?;
#             # 10.0 % obj: schema:Place. Cardinality: {1}
#    rdf:type  [<http://www.w3.org/2003/01/geo/wgs84_pos#SpatialThing>]  ?;
#             # 10.0 % obj: <http://www.w3.org/2003/01/geo/wgs84_pos#SpatialThing>. Cardinality: {1}
#    rdf:type  [dbo:HistoricPlace]  ?;
#             # 10.0 % obj: dbo:HistoricPlace. Cardinality: {1}
#    rdf:type  [<http://www.wikidata.org/entity/Q11173>]  ?;
#             # 10.0 % obj: <http://www.wikidata.org/entity/Q11173>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatCitrates>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/WikicatCitrates>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Citrate114604184>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Citrate114604184>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/Ester114850483>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/Ester114850483>. Cardinality: {1}
#    rdf:type  [<http://dbpedia.org/class/yago/OrganicCompound114727670>]  ?;
#             # 10.0 % obj: <http://dbpedia.org/class/yago/OrganicCompound114727670>. Cardinality: {1}
#    rdf:type  [dbo:ChemicalCompound]  ?;
#             # 10.0 % obj: dbo:ChemicalCompound. Cardinality: {1}
#    dbp:solubility  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:c  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:chebi  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:chembl  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:image  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:kegg  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:meltingPoint  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:pregnancyUs  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:routesOfAdministration  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:unii  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:dailymedid  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:licenceUs  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:meltingNotes  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:pregnancyUsComment  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbo:chEBI  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:chEMBL  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:kegg  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:developer  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:extraColumn  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:fam  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:headline  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:length  xsd:integer  *;
#             # 10.0 % obj: xsd:integer. Cardinality: {17}
#    dbp:modes  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:note  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {16}
#    dbp:platforms  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:platforms  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbp:publisher  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbp:released  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {3}
#    dbp:title  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {19}
#    dbp:totalLength  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:releaseDate  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbo:computingPlatform  IRI  *;
#             # 10.0 % obj: IRI. Cardinality: {3}
#    dbo:genre  IRI  *;
#             # 10.0 % obj: IRI. Cardinality: {2}
#    rdfs:seeAlso  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:country  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:country  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:coverArtist  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:coverArtist  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:isbn  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:isbnNote  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:language  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:language  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:origLangCode  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:titleOrig  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:translator  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbo:isbn  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbo:country  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbo:language  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbo:mediaType  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbo:coverArtist  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbo:literaryGenre  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbo:wikiPageRedirects  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:1a  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:1y  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:2a  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbp:2pp  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:2y  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbp:l  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:p  xsd:string  *;
#             # 10.0 % obj: xsd:string. Cardinality: {2}
#    dbp:s  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:t  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:w  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    <http://www.w3.org/2003/01/geo/wgs84_pos#lat>  xsd:float  ?;
#             # 10.0 % obj: xsd:float. Cardinality: {1}
#    <http://www.w3.org/2003/01/geo/wgs84_pos#long>  xsd:float  ?;
#             # 10.0 % obj: xsd:float. Cardinality: {1}
#    dbo:location  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:added  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:architect  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    dbp:architecture  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:builder  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:location  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:locmapin  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:mapCaption  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:nocat  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:nrhpType  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:refnum  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    <http://www.georss.org/georss/point>  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbo:area  xsd:float  ?;
#             # 10.0 % obj: xsd:float. Cardinality: {1}
#    dbo:nrhpReferenceNumber  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:yearOfConstruction  xsd:integer  ?;
#             # 10.0 % obj: xsd:integer. Cardinality: {1}
#    dbo:architect  IRI  ?;
#             # 10.0 % obj: IRI. Cardinality: {1}
#    <http://www.w3.org/2003/01/geo/wgs84_pos#geometry>  xsd:string  ?;
#             # 10.0 % obj: xsd:string. Cardinality: {1}
#    dbp:imagefile  xsd:string  ?
#             # 10.0 % obj: xsd:string. Cardinality: {1}
# }
