# %% [markdown]
# Para consultar datos, debemos tener 1) datos, y 2) un sitio donde consultarlos.
#
# En el contexto de esta asignatura, se espera que hayas desarrollado ya tu propio conjunto de datos y sobre ellos harás las consultas que entregues. No obstante, para esta sesión, utilizaré datos de DBpedia.
#
# En cuanto a dónde colocar tus datos para consultas, necesitamos un endpoint de SPARQL. Existen muchas alternativas:
#
# * Fuseki (https://jena.apache.org/documentation/fuseki2/#download-fuseki), parte de Apache Jena. Utilizado, por ejemplo, en YAGO (https://yago-knowledge.org/).  Los datos se dividen en datasets aislados entre sí. Cada dataset tendrá su propia URL para exponer un endpoint para consultas. Esto no quiere decir que cada dataset consista en un único grafo. Se pueden introducir distintos grafos dentro de un mismo dataset, y consultarlos por separado en el mismo endpoint utilizando sentencias graph en SPARQL (el modelo de tripletas evolucionaría al modelo de quads).
#
# * GraphDB (https://graphdb.ontotext.com/). Habitual en muchas empresas, con soporte comercial, robusto y estable.
#
# * Virtuoso (https://vos.openlinksw.com/owiki/wiki/VOS/VOSDownload). Usado, por ejemplo, en DBpedia.  Muy consolidada y estable. Opción comercial y edición open source. Fama de eficiente con grandes volúmenes de datos, pero parece que hay propuestas más recientes que le aventajan en ese aspecto.
#
# * Blazegrph(https://blazegraph.com/). Usado, por ejemplo, en Wikidata. Puede manejar muchos datos con la infraestructura adecuada, pero en Wikidata comienza a dar problemas. Sin soporte desde 2020 (la mayoría de sus ingenieros fueron contratados por Amazon Neptune). A pesar de que siga en Wikidata, la falta de soporte lo hace una opción arriesgada.
#
# * QLever(https://github.com/ad-freiburg/QLever). Diseñado para funcionar bien con enormes volumenes de datos. Sus datos anunciados en presentaciones o documentos de investigación son espectaculares comparándolos con el rendimiento de otros motores, pero no está lo suficientemente probado en entornos reales. Implementado y mantenido por institución académica
#
# * Oxigraph (https://github.com/oxigraph/oxigraph). Implementado en Rust, prometedor. Iniciativa OpenSource.
#
# * RDFox (https://www.oxfordsemantic.tech/download). No sólo funciona como motor de SPARQL típico, soporte a razonadores.
#
# En esta asignatura no pretendemos convertirte en un experto o experta en la administración de ningún endpoint concreto. No nos meteremos, en ningún caso, a hacer condiguraciones avanzadas de permisos de los mismos. Sólo buscamos que sepas que existen alternativas y seas capaz de instalar, poblar con datos y utilizar unpar cualquier de enpoints. Si no tienes ninguna preferencia, una opción factible sería instalar Fuseki y GraphDB. En ambos casos, tanto la instalación como el despliegue son sencillos y autoexplicativos en su versión básica. Pero puedes probar cualquier otro.
#
# En este enlace encontrarás una lista (incompleta) de motores de SPARQL: https://en.wikipedia.org/wiki/List_of_SPARQL_implementations
#
# En este otro, una lista (incompleta) de algunos endpoint públicos asociados a algún KG en RDF que puedes explorar a través de consultas SPARQL: https://www.w3.org/wiki/SparqlEndpoints
#
#
# En este Jupyter vamos a experimentar con el endpoint de DBpedia. Escogiendo como dominio libros y entidades relacionadas, iremos poniendo ejemplos de consultas con mayor complejidad cada vez, que quizá te sirvan de inspiración para obtener consultas relacionadas con tu propio conjunto de datos.
#
# Ejecutaremos estas consultas contra el endpoint de SPARQL de DBpedia utilizando SPARQLWrapper. Si prefieres utilizar el interfaz web para ver los resultados de las consultas, tan sólo copia y pega el string de la consulta que corresponda en el interfaz web del endpoint de DBpedia: https://dbpedia.org/sparql/
#
# ADVERTENCIA: Si quieres ejecutar consultas contra tu propio endpoint con tus datos desde Jupyter, ten en cuenta que, por defecto, las referencias a localhost no podrán resolverse. Utiliza una URL pública fija en su lugar una vez tengas tu endpoint desplegado en un servidor. Esto aplica a Jupyter en Colab, pero no a Python. Si ejecutas cierta consulta desde la consola de tu equipo o desde cualqueir IDE, las referencias a localhost funcionarán sin problema.

# %% [markdown]
# ## ACLARACIÓN IMPORTANTE
#
# En las consultas de ejemplo contra el endpoint de DBpedia, utilizaemos prefijos comunes como:
# * dbr --> http://dbpedia.org/resource/  -> Espacio de nombres para entidades (instancias) en DBpedia.
# * dbo --> http://dbpedia.org/ontology/  -> Espacio de nombres para conceptos (clases) en DBpedia.
# * rdfs --> http://www.w3.org/2000/01/rdf-schema# --> Espacio de nombres para algunas propiedades especiales y habituales de rdf, como rdfs:label para etiquetas, rdfs:comment para descripciones o rdfs:seeAlso para relacionar conceptos mediante un tipo de relación de semántica inespecífica.
#
# Esto funcionará aunque no hagamos declaraciones de prefijos al principio de la consulta. Pero esto no significa que cualqueir consulta SPARQL en cualquier endpoint vaya a funcionar sin declarar prefijos. Ocurre que el endpoint público de DBpedia maneja unos cuantos prefijos y espacios de nombres extremadamente comúnes para ahorrarnos que los escribamos. Pero es una particularidad de esta instalación concreta de este endpoint, no podemos asumir que funcionará así en otros.

# %%
# !pip install sparqlwrapper
# Out:
# Collecting sparqlwrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting rdflib>=6.1.1 (from sparqlwrapper)
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib>=6.1.1->sparqlwrapper) (3.2.1)
# Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Downloading rdflib-7.1.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.9/564.9 kB 11.7 MB/s eta 0:00:00
# Installing collected packages: rdflib, sparqlwrapper
# Successfully installed rdflib-7.1.3 sparqlwrapper-2.0.0

# %%
#Consulta para encontrar URIs de libros

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""
    select * where {
# ?s a dbo:Book
}  LIMIT 100
  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="  ")
    print()
print("--------")
# Out:
# http://dbpedia.org/resource/Cabal_(novella)
# http://dbpedia.org/resource/Caddo_Valley_Academy_Complex
# http://dbpedia.org/resource/Cafe_Little_Wish
# http://dbpedia.org/resource/Cage_on_the_Sea
# http://dbpedia.org/resource/Caigentan
# http://dbpedia.org/resource/Calcium_beta-hydroxy-beta-methylbutyrate
# http://dbpedia.org/resource/Calcium_citrate_malate
# http://dbpedia.org/resource/Calcium_glubionate
# http://dbpedia.org/resource/Calcium_glucoheptonate
# http://dbpedia.org/resource/Calcium_gluconate
# http://dbpedia.org/resource/Calcium_glycerylphosphate
# http://dbpedia.org/resource/Calcium_pangamate
# http://dbpedia.org/resource/Calculating_God
# http://dbpedia.org/resource/Calculus
# http://dbpedia.org/resource/Calculus_on_Manifolds_(book)
# http://dbpedia.org/resource/California_Dreaming_(novel)
# http://dbpedia.org/resource/California_Manual_on_Uniform_Traffic_Control_Devices
# http://dbpedia.org/resource/Call_It_Courage
# http://dbpedia.org/resource/Call_Me_Dave
# http://dbpedia.org/resource/Call_Sign_Extortion_17
# http://dbpedia.org/resource/Call_for_the_Dead
# http://dbpedia.org/resource/Caltrate
# http://dbpedia.org/resource/Calypso_(book)
# http://dbpedia.org/resource/Cam_Burke
# http://dbpedia.org/resource/Camaya_Falls
# http://dbpedia.org/resource/Cambridge,_Corpus_Christi_College,_MS_178
# http://dbpedia.org/resource/Camera_Obscura_(novel)
# http://dbpedia.org/resource/Camera_obscura_(novel)
# http://dbpedia.org/resource/Campaign_Sourcebook_and_Catacomb_Guide
# http://dbpedia.org/resource/Campanology
# http://dbpedia.org/resource/Campbell's_Soup_Cans
# http://dbpedia.org/resource/Campus_novel
# http://dbpedia.org/resource/Can't_Buy_Me_Like
# http://dbpedia.org/resource/Canada_Land_Inventory
# http://dbpedia.org/resource/Canadian_Certificate_of_Identity
# http://dbpedia.org/resource/Canadian_Communications_Foundation
# http://dbpedia.org/resource/Cancer_Ward
# http://dbpedia.org/resource/Candide
# http://dbpedia.org/resource/Candy_(Brooks_novel)
# http://dbpedia.org/resource/Candy_Candy
# http://dbpedia.org/resource/Candyfloss_(novel)
# http://dbpedia.org/resource/Candyfreak
# http://dbpedia.org/resource/Cannabis:_The_Illegalization_of_Weed_in_America
# http://dbpedia.org/resource/Cannonball_(novel)
# http://dbpedia.org/resource/Cantata_(Stravinsky)
# http://dbpedia.org/resource/Cantata_Profana
# http://dbpedia.org/resource/Cantata_academica
# http://dbpedia.org/resource/Cantate!
# http://dbpedia.org/resource/Canto_da_Solidão
# http://dbpedia.org/resource/Canto_for_a_Gypsy
# http://dbpedia.org/resource/Capital,_Volume_III
# http://dbpedia.org/resource/Capital_and_Ideology
# http://dbpedia.org/resource/Capital_and_Interest
# http://dbpedia.org/resource/Capital_in_the_Twenty-First_Century
# http://dbpedia.org/resource/Capoeira:_The_History_of_an_Afro-Brazilian_Martial_Art
# http://dbpedia.org/resource/Cappadonna_Hits
# http://dbpedia.org/resource/Caps_for_Sale
# http://dbpedia.org/resource/Captain_Fantastic_and_the_Brown_Dirt_Cowboy
# http://dbpedia.org/resource/Captain_Tempesta
# http://dbpedia.org/resource/Captain_Underpants_and_the_Invasion...
# http://dbpedia.org/resource/Captain_Underpants_and_the_Revolting_Revenge_of_the_Radioactive_Robo-Boxers
# http://dbpedia.org/resource/Captain_from_Castile_(novel)
# http://dbpedia.org/resource/Car-Jacked_(novel)
# http://dbpedia.org/resource/Car_brez_zaklada
# http://dbpedia.org/resource/Carbon_Dreams
# http://dbpedia.org/resource/Carey_Baptist_College
# http://dbpedia.org/resource/Carl's_Afternoon_in_the_Park
# http://dbpedia.org/resource/Carl_Burgos
# http://dbpedia.org/resource/Carlos_Celdran
# http://dbpedia.org/resource/Carmen_Miserabile
# http://dbpedia.org/resource/Carpe_Jugulum
# http://dbpedia.org/resource/Carrie_(novel)
# http://dbpedia.org/resource/Carrion_Comfort
# http://dbpedia.org/resource/Carrying_the_Fire
# http://dbpedia.org/resource/Cars:_Radiator_Springs_Adventures
# http://dbpedia.org/resource/Cartography
# http://dbpedia.org/resource/Carver_(novel)
# http://dbpedia.org/resource/Cary_Bates
# http://dbpedia.org/resource/Casanova_(novel)
# http://dbpedia.org/resource/Case_Mansion
# http://dbpedia.org/resource/Casino_Royale_(novel)
# http://dbpedia.org/resource/Cass_Street_Park
# http://dbpedia.org/resource/Cassandra_(novel)
# http://dbpedia.org/resource/Cast_of_Criminals
# http://dbpedia.org/resource/Caste:_The_Origins_of_Our_Discontents
# http://dbpedia.org/resource/Castes_in_India:_Their_Mechanism,_Genesis_and_Development
# http://dbpedia.org/resource/Casual_peeps_at_Sophia
# http://dbpedia.org/resource/Cat_Country_(novel)
# http://dbpedia.org/resource/Cat_Girl_Alliance
# http://dbpedia.org/resource/Cat_O'Nine_Tales
# http://dbpedia.org/resource/Cat_and_Mouse_(novel)
# http://dbpedia.org/resource/Catalyst_(novel)
# http://dbpedia.org/resource/Catastrophe_(book)
# http://dbpedia.org/resource/Catch-22
# http://dbpedia.org/resource/Catch_Me_if_You_Can_(book)
# http://dbpedia.org/resource/Catch_the_Breeze
# http://dbpedia.org/resource/Categories_for_the_Working_Mathematician
# http://dbpedia.org/resource/Amblypoda
# http://dbpedia.org/resource/Ambrosian_Iliad
# http://dbpedia.org/resource/Ambrosio_de_Letinez
# --------

# %%
#Consulta para encontrar URIs de libros además de la(s) etiqueta(s) asociadas a estas URIs

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""
    select * where {
# ?s a dbo:Book ;
   rdfs:label ?label .
}  LIMIT 100
  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="  ")
    print()
print("--------")
# Out:
# http://dbpedia.org/resource/Cabal_(novella)  Cabal
# http://dbpedia.org/resource/Cabal_(novella)  Cabal (novella)
# http://dbpedia.org/resource/Cabal_(novella)  Cabal (romanzo)
# http://dbpedia.org/resource/Cabal_(novella)  Ночной народ (роман)
# http://dbpedia.org/resource/Cabal_(novella)  Кабал
# http://dbpedia.org/resource/Caddo_Valley_Academy_Complex  Caddo Valley Academy Complex
# http://dbpedia.org/resource/Cafe_Little_Wish  Cafe Little Wish
# http://dbpedia.org/resource/Cafe_Little_Wish  Cafe Little Wish
# http://dbpedia.org/resource/Cafe_Little_Wish  Cafe Little Wish
# http://dbpedia.org/resource/Cage_on_the_Sea  Cage on the Sea
# http://dbpedia.org/resource/Caigentan  Caigentan
# http://dbpedia.org/resource/Caigentan  Propos sur la racine des légumes
# http://dbpedia.org/resource/Caigentan  菜根譚
# http://dbpedia.org/resource/Caigentan  채근담
# http://dbpedia.org/resource/Caigentan  Caigentan
# http://dbpedia.org/resource/Caigentan  菜根譚
# http://dbpedia.org/resource/Calcium_beta-hydroxy-beta-methylbutyrate  Calcium beta-hydroxy-beta-methylbutyrate
# http://dbpedia.org/resource/Calcium_citrate_malate  Calcium citrate malate
# http://dbpedia.org/resource/Calcium_glubionate  Calcium glubionate
# http://dbpedia.org/resource/Calcium_glucoheptonate  Calcium glucoheptonate
# http://dbpedia.org/resource/Calcium_gluconate  غلوكونات الكالسيوم
# http://dbpedia.org/resource/Calcium_gluconate  Gluconat de calci
# http://dbpedia.org/resource/Calcium_gluconate  Glukonát vápenatý
# http://dbpedia.org/resource/Calcium_gluconate  Calciumgluconat
# http://dbpedia.org/resource/Calcium_gluconate  Gluconato cálcico
# http://dbpedia.org/resource/Calcium_gluconate  Calcium gluconate
# http://dbpedia.org/resource/Calcium_gluconate  Kalsium glukonat
# http://dbpedia.org/resource/Calcium_gluconate  Gluconato di calcio
# http://dbpedia.org/resource/Calcium_gluconate  Gluconate de calcium
# http://dbpedia.org/resource/Calcium_gluconate  グルコン酸カルシウム
# http://dbpedia.org/resource/Calcium_gluconate  Calciumgluconaat
# http://dbpedia.org/resource/Calcium_gluconate  Glukonian wapnia
# http://dbpedia.org/resource/Calcium_gluconate  Gluconato de cálcio
# http://dbpedia.org/resource/Calcium_gluconate  Глюконат кальция
# http://dbpedia.org/resource/Calcium_gluconate  葡萄糖酸钙
# http://dbpedia.org/resource/Calcium_gluconate  Глюконат кальцію
# http://dbpedia.org/resource/Calcium_glycerylphosphate  فوسفات غليسيريل الكالسيوم
# http://dbpedia.org/resource/Calcium_glycerylphosphate  Calcium glycerylphosphate
# http://dbpedia.org/resource/Calcium_glycerylphosphate  Glycérophosphate de calcium
# http://dbpedia.org/resource/Calcium_glycerylphosphate  Глицерофосфат кальция
# http://dbpedia.org/resource/Calcium_glycerylphosphate  Гліцерофосфат кальцію
# http://dbpedia.org/resource/Calcium_pangamate  Calcium pangamate
# http://dbpedia.org/resource/Calculating_God  Calculating God
# http://dbpedia.org/resource/Calculating_God  El cálculo de Dios
# http://dbpedia.org/resource/Calculating_God  Calculating God
# http://dbpedia.org/resource/Calculating_God  Calculating God
# http://dbpedia.org/resource/Calculating_God  L'equazione di Dio
# http://dbpedia.org/resource/Calculating_God  Вираховуючи Бога
# http://dbpedia.org/resource/Calculus  Calculus
# http://dbpedia.org/resource/Calculus  تفاضل وتكامل
# http://dbpedia.org/resource/Calculus  Càlcul infinitesimal
# http://dbpedia.org/resource/Calculus  Infinitezimální počet
# http://dbpedia.org/resource/Calculus  Infinitesimalrechnung
# http://dbpedia.org/resource/Calculus  Λογισμός
# http://dbpedia.org/resource/Calculus  Infinitezima kalkulo
# http://dbpedia.org/resource/Calculus  Cálculo infinitesimal
# http://dbpedia.org/resource/Calculus  Kalkulu infinitesimal
# http://dbpedia.org/resource/Calculus  Calcalas
# http://dbpedia.org/resource/Calculus  Calcul infinitésimal
# http://dbpedia.org/resource/Calculus  Kalkulus
# http://dbpedia.org/resource/Calculus  Calcolo infinitesimale
# http://dbpedia.org/resource/Calculus  미적분학
# http://dbpedia.org/resource/Calculus  微分積分学
# http://dbpedia.org/resource/Calculus  Rachunek różniczkowy i całkowy
# http://dbpedia.org/resource/Calculus  Wiskundige analyse
# http://dbpedia.org/resource/Calculus  Cálculo infinitesimal
# http://dbpedia.org/resource/Calculus  Математический анализ
# http://dbpedia.org/resource/Calculus  Infinitesimalkalkyl
# http://dbpedia.org/resource/Calculus  微积分学
# http://dbpedia.org/resource/Calculus  Диференціальне та інтегральне числення
# http://dbpedia.org/resource/Calculus_on_Manifolds_(book)  Calculus on Manifolds (book)
# http://dbpedia.org/resource/Calculus_on_Manifolds_(book)  Calculus on Manifolds (書籍)
# http://dbpedia.org/resource/California_Dreaming_(novel)  California Dreaming (novel)
# http://dbpedia.org/resource/California_Manual_on_Uniform_Traffic_Control_Devices  California Manual on Uniform Traffic Control Devices
# http://dbpedia.org/resource/Call_It_Courage  Call It Courage
# http://dbpedia.org/resource/Call_It_Courage  Odvaha (kniha)
# http://dbpedia.org/resource/Call_It_Courage  Le Garçon qui avait peur
# http://dbpedia.org/resource/Call_Me_Dave  Call Me Dave
# http://dbpedia.org/resource/Call_Sign_Extortion_17  Call Sign Extortion 17
# http://dbpedia.org/resource/Call_for_the_Dead  Call for the Dead
# http://dbpedia.org/resource/Call_for_the_Dead  Schatten von gestern
# http://dbpedia.org/resource/Call_for_the_Dead  Llamada para el muerto
# http://dbpedia.org/resource/Call_for_the_Dead  L'Appel du mort
# http://dbpedia.org/resource/Call_for_the_Dead  Chiamata per il morto
# http://dbpedia.org/resource/Call_for_the_Dead  Budzenie zmarłych
# http://dbpedia.org/resource/Call_for_the_Dead  Call for the Dead
# http://dbpedia.org/resource/Caltrate  Caltrate
# http://dbpedia.org/resource/Calypso_(book)  Calypso (book)
# http://dbpedia.org/resource/Cam_Burke  Cam Burke
# http://dbpedia.org/resource/Camaya_Falls  Camaya Falls
# http://dbpedia.org/resource/Camaya_Falls  Cascadas de Camaya
# http://dbpedia.org/resource/Cambridge,_Corpus_Christi_College,_MS_178  Cambridge, Corpus Christi College, MS 178
# http://dbpedia.org/resource/Camera_Obscura_(novel)  Camera Obscura (novel)
# http://dbpedia.org/resource/Camera_obscura_(novel)  Camera obscura (novel)
# http://dbpedia.org/resource/Campaign_Sourcebook_and_Catacomb_Guide  Campaign Sourcebook and Catacomb Guide
# http://dbpedia.org/resource/Campanology  Campanology
# http://dbpedia.org/resource/Campanology  Kampanologie
# http://dbpedia.org/resource/Campanology  Campanologie
# http://dbpedia.org/resource/Campanology  Clingireacht
# http://dbpedia.org/resource/Campanology  Campanologie
# --------

# %%
# Libros y sus etiquetas, pero sólo aquellas etiquetas que se señale explícitamente que están en español.


from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""
    select * where {
# ?s a dbo:Book ;
   rdfs:label ?label .

   FILTER(lang(?label) = "es")
}  LIMIT 100
  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="  ")
    print()
print("--------")
# Out:
# http://dbpedia.org/resource/Cabal_(novella)  Cabal
# http://dbpedia.org/resource/Calcium_gluconate  Gluconato cálcico
# http://dbpedia.org/resource/Calculating_God  El cálculo de Dios
# http://dbpedia.org/resource/Calculus  Cálculo infinitesimal
# http://dbpedia.org/resource/Call_for_the_Dead  Llamada para el muerto
# http://dbpedia.org/resource/Camaya_Falls  Cascadas de Camaya
# http://dbpedia.org/resource/Campbell's_Soup_Cans  Latas de sopa Campbell
# http://dbpedia.org/resource/Cancer_Ward  Pabellón del cáncer
# http://dbpedia.org/resource/Candide  Cándido
# http://dbpedia.org/resource/Candy_Candy  Candy Candy
# http://dbpedia.org/resource/Capital_in_the_Twenty-First_Century  El capital en el siglo XXI
# http://dbpedia.org/resource/Captain_Fantastic_and_the_Brown_Dirt_Cowboy  Captain Fantastic and the Brown Dirt Cowboy
# http://dbpedia.org/resource/Captain_Tempesta  El capitán Tormenta
# http://dbpedia.org/resource/Carpe_Jugulum  Carpe Jugulum
# http://dbpedia.org/resource/Carrie_(novel)  Carrie (novela)
# http://dbpedia.org/resource/Carrion_Comfort  Los vampiros de la mente
# http://dbpedia.org/resource/Cars:_Radiator_Springs_Adventures  Cars: Radiator Springs Adventures
# http://dbpedia.org/resource/Cartography  Cartografía
# http://dbpedia.org/resource/Casino_Royale_(novel)  Casino Royale (novela)
# http://dbpedia.org/resource/Catch-22  Trampa 22 (libro)
# http://dbpedia.org/resource/Ambrosian_Iliad  Ilias Picta
# http://dbpedia.org/resource/Amduat  Libro del Amduat
# http://dbpedia.org/resource/America's_60_Families  60 Familias de los Estados Unidos
# http://dbpedia.org/resource/America's_Great_Depression  La Gran Depresión (libro)
# http://dbpedia.org/resource/American_Cookery  American Cookery
# http://dbpedia.org/resource/American_Theocracy  American Theocracy
# http://dbpedia.org/resource/Americanah  Americanah
# http://dbpedia.org/resource/Amerika_(novel)  América (novela)
# http://dbpedia.org/resource/Amok_(novella)  Amok (libro)
# http://dbpedia.org/resource/Among_Others  Entre extraños
# http://dbpedia.org/resource/Amsterdam_(novel)  Ámsterdam (novela)
# http://dbpedia.org/resource/Amulet_(novel)  Amuleto (novela)
# http://dbpedia.org/resource/A_Clockwork_Orange  La naranja mecánica (desambiguación)
# http://dbpedia.org/resource/Bay_Psalm_Book  Bay Psalm Book
# http://dbpedia.org/resource/Beard  Barba
# http://dbpedia.org/resource/Beastly  Beastly
# http://dbpedia.org/resource/Beau_Geste  Beau Geste
# http://dbpedia.org/resource/Beautiful_Chaos_(Garcia_and_Stohl_novel)  Hermoso caos
# http://dbpedia.org/resource/Beautiful_Creatures_(novel)  Hermosas criaturas
# http://dbpedia.org/resource/Beautiful_Darkness  Hermosa oscuridad
# http://dbpedia.org/resource/Beautiful_Disaster_(novel)  Maravilloso Desastre
# http://dbpedia.org/resource/Beauty_and_Sadness_(novel)  Lo bello y lo triste
# http://dbpedia.org/resource/Beck's_triad_(cardiology)  Tríada de Beck (Cardiología)
# http://dbpedia.org/resource/Beggars_in_Spain  Mendigos en España
# http://dbpedia.org/resource/Behavioral_ecology  Ecología del comportamiento
# http://dbpedia.org/resource/Behind_Her_Eyes_(novel)  Behind Her Eyes
# http://dbpedia.org/resource/Behind_the_Curtain  Detrás del telón
# http://dbpedia.org/resource/Behold_the_Man_(novel)  He aquí el hombre
# http://dbpedia.org/resource/Beige_Book  Libro beige
# http://dbpedia.org/resource/Beige_Planet_Mars  Beige Planet Mars
# http://dbpedia.org/resource/Beijing_Coma  Pekín en Coma
# http://dbpedia.org/resource/Being_and_Nothingness  El ser y la nada
# http://dbpedia.org/resource/Being_and_Time  Ser y tiempo
# http://dbpedia.org/resource/Beit_Yosef_(book)  Beit Yossef
# http://dbpedia.org/resource/Bel-Ami  Bel Ami
# http://dbpedia.org/resource/Belgic_Confession  Confesión belga
# http://dbpedia.org/resource/Belle_du_Seigneur  Bella del Señor
# http://dbpedia.org/resource/Belles_Heures_of_Jean_de_France,_Duc_de_Berry  Las bellas horas de Jean de Berry
# http://dbpedia.org/resource/Belmont_Report  Informe Belmont
# http://dbpedia.org/resource/Beloved_(novel)  Beloved (novela)
# http://dbpedia.org/resource/Ben,_in_the_World  Ben, en el mundo
# http://dbpedia.org/resource/Beneath_the_Wheel  Bajo las ruedas
# http://dbpedia.org/resource/Pramface  Pramface (serie de televisión)
# http://dbpedia.org/resource/Pre-Madonna  Pre-Madonna
# http://dbpedia.org/resource/Preload_(cardiology)  Precarga
# http://dbpedia.org/resource/Presumed_Innocent_(novel)  Presunto inocente
# http://dbpedia.org/resource/Pride_and_Prejudice  Orgullo y prejuicio (novela)
# http://dbpedia.org/resource/Prime_k-tuple  K-tupla de números primos
# http://dbpedia.org/resource/Prince_Caspian  El príncipe Caspian
# http://dbpedia.org/resource/Principia_Mathematica  Principia Mathematica
# http://dbpedia.org/resource/Prisoners_of_the_Sun  El templo del Sol
# http://dbpedia.org/resource/Privilegium_Maius  Privilegium Maius
# http://dbpedia.org/resource/Programme_for_International_Student_Assessment  Informe PISA
# http://dbpedia.org/resource/Project_Plowshare  Operación Plowshare
# http://dbpedia.org/resource/Proxemics  Proxemia
# http://dbpedia.org/resource/Prueba_de_Selección_Universitaria  Prueba de Selección Universitaria
# http://dbpedia.org/resource/Psalms  Libro de los salmos
# http://dbpedia.org/resource/Psalter  Salterio (libro de salmos)
# http://dbpedia.org/resource/Psychological_Types  Tipos psicológicos
# http://dbpedia.org/resource/Psychology  Psicología
# http://dbpedia.org/resource/Psychoneuroendocrinology  Psiconeuroendocrinología
# http://dbpedia.org/resource/Public_policy  Políticas públicas
# http://dbpedia.org/resource/Pure_(Miller_novel)  Pure (novela)
# http://dbpedia.org/resource/Purple_Hibiscus  Purple Hibiscus
# http://dbpedia.org/resource/Puss_in_Boots  El Gato con Botas
# http://dbpedia.org/resource/Pyomo  Pyomo
# http://dbpedia.org/resource/Pyramids_(novel)  Pirómides
# http://dbpedia.org/resource/Qidan_Guo_Zhi  Qidan Guozhi
# http://dbpedia.org/resource/Quality_management_system  Sistema de gestión de la calidad
# http://dbpedia.org/resource/Quassia  Quassia
# http://dbpedia.org/resource/Queen's_Road,_Hong_Kong  Queen's Road (Hong Kong)
# http://dbpedia.org/resource/Queen_Victoria's_journals  Diarios de Victoria del Reino Unido
# http://dbpedia.org/resource/Quenta_Silmarillion  Quenta Silmarillion
# http://dbpedia.org/resource/Querimonia  Era Querimònia
# http://dbpedia.org/resource/Quest_for_a_Throne  A la conquista de un imperio
# http://dbpedia.org/resource/Quid_(encyclopedia)  Quid (enciclopedia)
# http://dbpedia.org/resource/Quidditch_Through_the_Ages  Quidditch a través de los tiempos
# http://dbpedia.org/resource/Robinson_Crusoe  Robinson Crusoe
# http://dbpedia.org/resource/Robotics;Notes  Robotics;Notes
# http://dbpedia.org/resource/Rock_Islands  Islas Chelbacheb
# --------

# %%
# Lo mismo de antes, pero sólo novelas de fantasía


from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""
    select * where {
# ?s a dbo:Book ;
   rdfs:label ?label ;
   dbo:literaryGenre dbr:Fantasy_novel .

   FILTER(lang(?label) = "es")

}  LIMIT 100
  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="  ")
    print()
print("--------")
# Out:
# http://dbpedia.org/resource/Beautiful_Chaos_(Garcia_and_Stohl_novel)  Hermoso caos
# http://dbpedia.org/resource/Beautiful_Creatures_(novel)  Hermosas criaturas
# http://dbpedia.org/resource/Beautiful_Darkness  Hermosa oscuridad
# http://dbpedia.org/resource/Midnight_Sun_(Meyer_novel)  Sol de medianoche (novela)
# http://dbpedia.org/resource/Momo_(novel)  Momo (novela)
# http://dbpedia.org/resource/The_Amulet_of_Samarkand  El amuleto de Samarkanda
# http://dbpedia.org/resource/Day_Watch_(novel)  Guardianes del día
# http://dbpedia.org/resource/Dead_Until_Dark  Muerto hasta el anochecer
# http://dbpedia.org/resource/Dead_as_a_Doornail  Más muerto que nunca
# http://dbpedia.org/resource/All_Together_Dead  De muerto en peor
# http://dbpedia.org/resource/All_Together_Dead  Todos juntos y muertos
# http://dbpedia.org/resource/Hush,_Hush  Hush, Hush (novela)
# http://dbpedia.org/resource/Beyond_the_Shadows  Más allá de las sombras (novela)
# http://dbpedia.org/resource/Dead_Reckoning_(novel)  El día del juicio mortal
# http://dbpedia.org/resource/Dead_and_Gone_(novel)  Muerto y enterrado
# http://dbpedia.org/resource/Dead_in_the_Family  Muerto en familia
# http://dbpedia.org/resource/Deadhouse_Gates  Las puertas de la Casa de la Muerte
# http://dbpedia.org/resource/Declare  Declara (novela)
# http://dbpedia.org/resource/Definitely_Dead  Definitivamente muerta
# http://dbpedia.org/resource/The_Alchemist_(novel)  El alquimista (novela)
# http://dbpedia.org/resource/The_Night_Land  El reino de la noche
# http://dbpedia.org/resource/The_Book_of_Three  El libro de los tres
# http://dbpedia.org/resource/Memories_of_Ice  Memorias del hielo
# http://dbpedia.org/resource/Night_Watch_(Lukyanenko_novel)  Guardianes de la noche
# http://dbpedia.org/resource/Oath_Breaker_(novel)  El juramento de Torak
# http://dbpedia.org/resource/Outcast_(Paver_novel)  La hechicera (novela)
# http://dbpedia.org/resource/Midnight_Tides  Mareas de medianoche
# http://dbpedia.org/resource/The_Golem's_Eye  El ojo del Golem
# http://dbpedia.org/resource/Clockwork_Prince  Príncipe mecánico
# http://dbpedia.org/resource/Clockwork_Princess  Princesa mecánica
# http://dbpedia.org/resource/Mistborn:_The_Well_of_Ascension  El pozo de la ascensión
# http://dbpedia.org/resource/The_Last_Olympian  El último héroe del Olimpo
# http://dbpedia.org/resource/The_Little_Vampire_(book_series)  El pequeño vampiro (saga)
# http://dbpedia.org/resource/The_Lost_Hero  El héroe perdido
# http://dbpedia.org/resource/The_Magicians'_Guild  El gremio de los magos
# http://dbpedia.org/resource/The_Mark_of_Athena  La marca de Atenea
# http://dbpedia.org/resource/The_Once_and_Future_King  Camelot (novelas)
# http://dbpedia.org/resource/The_Red_Pyramid  La pirámide roja
# http://dbpedia.org/resource/The_Son_of_Neptune  El hijo de Neptuno
# http://dbpedia.org/resource/The_Summer_Tree  El árbol del verano
# http://dbpedia.org/resource/The_Way_of_Shadows  El camino de las sombras (novela)
# http://dbpedia.org/resource/The_Wonderful_Wizard_of_Oz  El maravilloso mago de Oz
# http://dbpedia.org/resource/Living_Dead_in_Dallas  Living Dead in Dallas
# http://dbpedia.org/resource/Skulduggery_Pleasant  Detective Esqueleto
# http://dbpedia.org/resource/Skulduggery_Pleasant_(novel)  Skulduggery pleasant
# http://dbpedia.org/resource/Clockwork_Angel  Ángel mecánico
# http://dbpedia.org/resource/Club_Dead  El club de los muertos
# http://dbpedia.org/resource/From_Dead_to_Worse  De muerto en peor
# http://dbpedia.org/resource/From_Dead_to_Worse  Todos juntos y muertos
# http://dbpedia.org/resource/House_of_Chains  La Casa de Cadenas
# http://dbpedia.org/resource/Passion_(novel)  La trampa del amor
# http://dbpedia.org/resource/Spirit_Walker_(novel)  El clan de la foca
# http://dbpedia.org/resource/The_Subtle_Knife  La daga
# http://dbpedia.org/resource/The_Amber_Spyglass  La materia oscura
# http://dbpedia.org/resource/The_Amber_Spyglass  El catalejo lacado
# http://dbpedia.org/resource/Tuck_Everlasting  Tuck Everlasting
# http://dbpedia.org/resource/Twilight_(Meyer_novel)  Crepúsculo (novela)
# http://dbpedia.org/resource/Twilight_(Meyer_novel)  Profundidades
# http://dbpedia.org/resource/Twilight_(Meyer_novel)  Túneles (novela)
# http://dbpedia.org/resource/Dragonsbane  Vencer al dragón
# http://dbpedia.org/resource/Dreamsongs:_A_RRetrospective  George R. R. Martin: Autobiografía literaria
# http://dbpedia.org/resource/Jumanji_(picture_book)  Jumanji
# http://dbpedia.org/resource/Shadow's_Edge  Al filo de las sombras
# http://dbpedia.org/resource/The_City_of_Dreaming_Books  La ciudad de los libros soñadores
# http://dbpedia.org/resource/Wolf_Brother  Hermano lobo (novela)
# http://dbpedia.org/resource/Fantastic_Beasts_and_Where_to_Find_Them  Animales fantásticos y dónde encontrarlos
# http://dbpedia.org/resource/Fallen_(Kate_novel)  Oscuros (novela)
# http://dbpedia.org/resource/Forest_of_the_Pygmies  El bosque de los pigmeos
# http://dbpedia.org/resource/Grave_Sight  El club de los muertos
# http://dbpedia.org/resource/Rapture_(Kate_novel)  La primera maldición
# http://dbpedia.org/resource/Grendel_(novel)  Grendel (novela)
# http://dbpedia.org/resource/Harry_Potter_and_the_Chamber_of_Secrets  Harry Potter y la cámara secreta
# http://dbpedia.org/resource/Harry_Potter_and_the_Chamber_of_Secrets  Harry Potter y la cámara secreta (película)
# http://dbpedia.org/resource/Harry_Potter_and_the_Goblet_of_Fire  Harry Potter y el cáliz de fuego
# http://dbpedia.org/resource/Harry_Potter_and_the_Half-Blood_Prince  Harry Potter y el misterio del príncipe
# http://dbpedia.org/resource/Harry_Potter_and_the_Order_of_the_Phoenix  Harry Potter y la Orden del Fénix
# http://dbpedia.org/resource/Harry_Potter_and_the_Philosopher's_Stone  Harry Potter y la piedra filosofal
# http://dbpedia.org/resource/Harry_Potter_and_the_Prisoner_of_Azkaban  Harry Potter y el prisionero de Azkaban
# http://dbpedia.org/resource/The_Gathering_Storm_(novel)  La tormenta (novela)
# http://dbpedia.org/resource/The_Hidden_Oracle  El oráculo oculto
# http://dbpedia.org/resource/The_House_of_Hades  La casa de Hades
# http://dbpedia.org/resource/ATLA_–_A_Story_of_the_Lost_Island  Atla
# http://dbpedia.org/resource/A_Fine_and_Private_Place  Un lugar agradable y tranquilo
# http://dbpedia.org/resource/A_Great_and_Terrible_Beauty  La Orden de la Academia Spence
# http://dbpedia.org/resource/A_Memory_of_Light  Un recuerdo de luz
# http://dbpedia.org/resource/A_Touch_of_Dead  Una pizca de muerte
# http://dbpedia.org/resource/Across_the_Nightingale_Floor  El suelo del ruiseñor
# http://dbpedia.org/resource/Blood_Follows  Blood Follows
# http://dbpedia.org/resource/Blood_and_Chocolate_(novel)  Blood and Chocolate (novela)
# http://dbpedia.org/resource/Eclipse_(Meyer_novel)  Eclipse (novela)
# http://dbpedia.org/resource/Here,_There_Be_Dragons  Tierra de dragones
# http://dbpedia.org/resource/Torment_(novel)  El poder de las sombras
# http://dbpedia.org/resource/Wings_(Pike_novel)  Alas (novela)
# http://dbpedia.org/resource/Mistborn:_Shadows_of_Self  Sombras de identidad
# http://dbpedia.org/resource/Mistborn:_The_Alloy_of_Law  Aleación de ley
# http://dbpedia.org/resource/Mistborn:_The_Final_Empire  El imperio final
# http://dbpedia.org/resource/Mistborn:_The_Hero_of_Ages  El héroe de las eras
# http://dbpedia.org/resource/Mistborn:_The_Lost_Metal  El metal perdido
# http://dbpedia.org/resource/Artemis_Fowl:_The_Eternity_Code  Artemis Fowl: El Cubo B
# http://dbpedia.org/resource/Artemis_Fowl_and_the_Arctic_Incident  Artemis Fowl: La cuenta atrás
# --------

# %%
# Ya no quiero saber la URI de las novelas, pero sí quiero conocer la URI del autor o autores de cada libro


from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""
    select ?label ?author where {
# ?s a dbo:Book ;
   rdfs:label ?label ;
   dbo:literaryGenre dbr:Fantasy_novel ;
   dbo:author ?author .

   FILTER(lang(?label) = "es")

}  LIMIT 100
  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="  ")
    print()
print("--------")
# Out:
# Hermoso caos  http://dbpedia.org/resource/Margaret_Stohl
# Hermoso caos  http://dbpedia.org/resource/Kami_Garcia
# Hermosas criaturas  http://dbpedia.org/resource/Margaret_Stohl
# Hermosas criaturas  http://dbpedia.org/resource/Kami_Garcia
# Hermosa oscuridad  http://dbpedia.org/resource/Margaret_Stohl
# Hermosa oscuridad  http://dbpedia.org/resource/Kami_Garcia
# Sol de medianoche (novela)  http://dbpedia.org/resource/Stephenie_Meyer
# Momo (novela)  http://dbpedia.org/resource/Michael_Ende
# El amuleto de Samarkanda  http://dbpedia.org/resource/Jonathan_Stroud
# Muerto hasta el anochecer  http://dbpedia.org/resource/Charlaine_Harris
# Más muerto que nunca  http://dbpedia.org/resource/Charlaine_Harris
# De muerto en peor  http://dbpedia.org/resource/Charlaine_Harris
# Todos juntos y muertos  http://dbpedia.org/resource/Charlaine_Harris
# Hush, Hush (novela)  http://dbpedia.org/resource/Becca_Fitzpatrick
# Más allá de las sombras (novela)  http://dbpedia.org/resource/Brent_Weeks
# El día del juicio mortal  http://dbpedia.org/resource/Charlaine_Harris
# Muerto y enterrado  http://dbpedia.org/resource/Charlaine_Harris
# Muerto en familia  http://dbpedia.org/resource/Charlaine_Harris
# Las puertas de la Casa de la Muerte  http://dbpedia.org/resource/Steven_Erikson
# Declara (novela)  http://dbpedia.org/resource/Tim_Powers
# Definitivamente muerta  http://dbpedia.org/resource/Charlaine_Harris
# El alquimista (novela)  http://dbpedia.org/resource/Paulo_Coelho
# El reino de la noche  http://dbpedia.org/resource/William_Hope_Hodgson
# El libro de los tres  http://dbpedia.org/resource/Lloyd_Alexander
# Memorias del hielo  http://dbpedia.org/resource/Steven_Erikson
# Guardianes de la noche  http://dbpedia.org/resource/Sergei_Lukyanenko
# El juramento de Torak  http://dbpedia.org/resource/Michelle_Paver
# La hechicera (novela)  http://dbpedia.org/resource/Michelle_Paver
# Mareas de medianoche  http://dbpedia.org/resource/Steven_Erikson
# El ojo del Golem  http://dbpedia.org/resource/Jonathan_Stroud
# Príncipe mecánico  http://dbpedia.org/resource/Cassandra_Clare
# Princesa mecánica  http://dbpedia.org/resource/Cassandra_Clare
# El pozo de la ascensión  http://dbpedia.org/resource/Brandon_Sanderson
# El último héroe del Olimpo  http://dbpedia.org/resource/Rick_Riordan
# El pequeño vampiro (saga)  http://dbpedia.org/resource/Angela_Sommer-Bodenburg
# El héroe perdido  http://dbpedia.org/resource/Rick_Riordan
# El gremio de los magos  http://dbpedia.org/resource/Trudi_Canavan
# La marca de Atenea  http://dbpedia.org/resource/Rick_Riordan
# Camelot (novelas)  http://dbpedia.org/resource/T._H._White
# La pirámide roja  http://dbpedia.org/resource/Rick_Riordan
# El hijo de Neptuno  http://dbpedia.org/resource/Rick_Riordan
# El árbol del verano  http://dbpedia.org/resource/Guy_Gavriel_Kay
# El camino de las sombras (novela)  http://dbpedia.org/resource/Brent_Weeks
# El maravilloso mago de Oz  http://dbpedia.org/resource/L._Frank_Baum
# Living Dead in Dallas  http://dbpedia.org/resource/Charlaine_Harris
# Detective Esqueleto  http://dbpedia.org/resource/Derek_Landy
# Skulduggery pleasant  http://dbpedia.org/resource/Derek_Landy
# Ángel mecánico  http://dbpedia.org/resource/Cassandra_Clare
# El club de los muertos  http://dbpedia.org/resource/Charlaine_Harris
# De muerto en peor  http://dbpedia.org/resource/Charlaine_Harris
# Todos juntos y muertos  http://dbpedia.org/resource/Charlaine_Harris
# La Casa de Cadenas  http://dbpedia.org/resource/Steven_Erikson
# La trampa del amor  http://dbpedia.org/resource/Lauren_Kate
# El clan de la foca  http://dbpedia.org/resource/Michelle_Paver
# La daga  http://dbpedia.org/resource/Philip_Pullman
# La materia oscura  http://dbpedia.org/resource/Philip_Pullman
# El catalejo lacado  http://dbpedia.org/resource/Philip_Pullman
# Tuck Everlasting  http://dbpedia.org/resource/Natalie_Babbitt
# Crepúsculo (novela)  http://dbpedia.org/resource/Stephenie_Meyer
# Profundidades  http://dbpedia.org/resource/Stephenie_Meyer
# Túneles (novela)  http://dbpedia.org/resource/Stephenie_Meyer
# Vencer al dragón  http://dbpedia.org/resource/Barbara_Hambly
# George R. R. Martin: Autobiografía literaria  http://dbpedia.org/resource/George_R.R._Martin
# Jumanji  http://dbpedia.org/resource/Chris_Van_Allsburg
# Al filo de las sombras  http://dbpedia.org/resource/Brent_Weeks
# La ciudad de los libros soñadores  http://dbpedia.org/resource/Walter_Moers
# Hermano lobo (novela)  http://dbpedia.org/resource/Michelle_Paver
# Animales fantásticos y dónde encontrarlos  http://dbpedia.org/resource/J._K._Rowling
# Animales fantásticos y dónde encontrarlos  http://dbpedia.org/resource/Newt_Scamander
# Oscuros (novela)  http://dbpedia.org/resource/Lauren_Kate
# El bosque de los pigmeos  http://dbpedia.org/resource/Isabel_Allende
# El club de los muertos  http://dbpedia.org/resource/Charlaine_Harris
# La primera maldición  http://dbpedia.org/resource/Lauren_Kate
# Grendel (novela)  http://dbpedia.org/resource/John_Gardner_(American_writer)
# Harry Potter y la cámara secreta  http://dbpedia.org/resource/J._K._Rowling
# Harry Potter y la cámara secreta (película)  http://dbpedia.org/resource/J._K._Rowling
# Harry Potter y el cáliz de fuego  http://dbpedia.org/resource/J._K._Rowling
# Harry Potter y el misterio del príncipe  http://dbpedia.org/resource/J.K._Rowling
# Harry Potter y la Orden del Fénix  http://dbpedia.org/resource/J._K._Rowling
# Harry Potter y la piedra filosofal  http://dbpedia.org/resource/J._K._Rowling
# Harry Potter y el prisionero de Azkaban  http://dbpedia.org/resource/J._K._Rowling
# La tormenta (novela)  http://dbpedia.org/resource/Brandon_Sanderson
# La tormenta (novela)  http://dbpedia.org/resource/Robert_Jordan
# El oráculo oculto  http://dbpedia.org/resource/Rick_Riordan
# La casa de Hades  http://dbpedia.org/resource/Rick_Riordan
# Atla  http://dbpedia.org/resource/Ann_Eliza_Smith
# Un lugar agradable y tranquilo  http://dbpedia.org/resource/Peter_S._Beagle
# La Orden de la Academia Spence  http://dbpedia.org/resource/Libba_Bray
# Un recuerdo de luz  http://dbpedia.org/resource/Brandon_Sanderson
# Un recuerdo de luz  http://dbpedia.org/resource/Robert_Jordan
# Una pizca de muerte  http://dbpedia.org/resource/Charlaine_Harris
# El suelo del ruiseñor  http://dbpedia.org/resource/Lian_Hearn
# Blood Follows  http://dbpedia.org/resource/Steven_Erikson
# Blood and Chocolate (novela)  http://dbpedia.org/resource/Annette_Curtis_Klause
# Eclipse (novela)  http://dbpedia.org/resource/Stephenie_Meyer
# Tierra de dragones  http://dbpedia.org/resource/James_A._Owen
# El poder de las sombras  http://dbpedia.org/resource/Lauren_Kate
# Alas (novela)  http://dbpedia.org/resource/Aprilynne_Pike
# Sombras de identidad  http://dbpedia.org/resource/Brandon_Sanderson
# Aleación de ley  http://dbpedia.org/resource/Brandon_Sanderson
# --------

# %%
# Lo de antes, pero con el nombre real del autor, no su URI

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""
    select ?label ?nameAuthor where {
# ?s a dbo:Book ;
   rdfs:label ?label ;
   dbo:literaryGenre dbr:Fantasy_novel ;
   dbo:author ?author .

   # ?author dbp:name ?nameAuthor .

   FILTER(lang(?label) = "es")

}  LIMIT 100
  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="       ")
    print()
print("--------")
# Out:
# Príncipe mecánico       Cassandra Clare
# Princesa mecánica       Cassandra Clare
# Ángel mecánico       Cassandra Clare
# Hush, Hush (novela)       Becca Fitzpatrick
# El pozo de la ascensión       Brandon Sanderson
# La tormenta (novela)       Brandon Sanderson
# Un recuerdo de luz       Brandon Sanderson
# Sombras de identidad       Brandon Sanderson
# Aleación de ley       Brandon Sanderson
# El imperio final       Brandon Sanderson
# El héroe de las eras       Brandon Sanderson
# El metal perdido       Brandon Sanderson
# Torres de medianoche       Brandon Sanderson
# El aliento de los dioses       Brandon Sanderson
# Más allá de las sombras (novela)       Brent Weeks
# El camino de las sombras (novela)       Brent Weeks
# Al filo de las sombras       Brent Weeks
# Detective Esqueleto       Derek Landy
# Skulduggery pleasant       Derek Landy
# Blood and Chocolate (novela)       Annette Curtis Klause
# La historia del doctor Dolittle       Hugh Lofting
# El amuleto de Samarkanda       Jonathan Stroud
# El ojo del Golem       Jonathan Stroud
# El alquimista (novela)       Paulo Coelho
# Un lugar agradable y tranquilo       Peter S. Beagle
# La tormenta (novela)       Robert Jordan
# Un recuerdo de luz       Robert Jordan
# Torres de medianoche       Robert Jordan
# Jumanji       Chris Van Allsburg
# World of Warcraft: Arthas el Ascenso del Rey Exanime       Christie Golden
# Artemis Fowl: El Cubo B       Eoin Colfer
# Artemis Fowl: La cuenta atrás       Eoin Colfer
# Artemis Fowl: Encuentro en el Ártico       Eoin Colfer
# Artemis Fowl: La venganza de Opal       Eoin Colfer
# El pequeño vampiro (saga)       Angela Sommer-Bodenburg
# Atla       Ann Eliza Smith
# Alas (novela)       Aprilynne Pike
# Alicia para los pequeños       Lewis Carroll
# La Orden de la Academia Spence       Libba Bray
# La Torre Oscura V: lobos del Calla       Stephen King
# Los ojos del dragón       Stephen King
# Sol de medianoche (novela)       Stephenie Meyer
# Crepúsculo (novela)       Stephenie Meyer
# Profundidades       Stephenie Meyer
# Túneles (novela)       Stephenie Meyer
# Eclipse (novela)       Stephenie Meyer
# La segunda vida de Bree Tanner       Stephenie Meyer
# Las puertas de la Casa de la Muerte       Steven Erikson
# Memorias del hielo       Steven Erikson
# Mareas de medianoche       Steven Erikson
# La Casa de Cadenas       Steven Erikson
# Blood Follows       Steven Erikson
# Hermoso caos       Margaret Stohl
# Hermosas criaturas       Margaret Stohl
# Hermosa oscuridad       Margaret Stohl
# Vencer al dragón       Barbara Hambly
# El regreso del peregrino       Clive Staples Lewis
# El regreso del peregrino       C. S. Lewis
# El regreso del peregrino       C. S.  Lewis
# Declara (novela)       Tim Powers
# El gremio de los magos       Trudi Canavan
# El reino de la noche       William Hope Hodgson
# The Somnambulist       Jonathan Barnes
# Eternidad (novela de Alyson Noël)       Alyson Noël
# El árbol del verano       Guy Gavriel Kay
# Ella y Allan       H. Rider Haggard
# El bosque de los pigmeos       Isabel Allende
# Animales fantásticos y dónde encontrarlos       J. K. Rowling
# Harry Potter y la cámara secreta       J. K. Rowling
# Harry Potter y la cámara secreta (película)       J. K. Rowling
# Harry Potter y el cáliz de fuego       J. K. Rowling
# Harry Potter y la Orden del Fénix       J. K. Rowling
# Harry Potter y la piedra filosofal       J. K. Rowling
# Harry Potter y el prisionero de Azkaban       J. K. Rowling
# La leyenda de Sigurd y Gudrún       J. R. R. Tolkien
# Tierra de dragones       James A. Owen
# Grendel (novela)       John Gardner
# Hermoso caos       Kami Garcia
# Hermosas criaturas       Kami Garcia
# Hermosa oscuridad       Kami Garcia
# El maravilloso mago de Oz       L. Frank Baum
# Camelot (novelas)       T. H.  White
# Camelot (novelas)       T. H. White
# La daga       Philip Pullman
# La materia oscura       Philip Pullman
# El catalejo lacado       Philip Pullman
# Momo (novela)       Michael Ende
# El juramento de Torak       Michelle Paver
# La hechicera (novela)       Michelle Paver
# El clan de la foca       Michelle Paver
# Hermano lobo (novela)       Michelle Paver
# El devorador de almas       Michelle Paver
# El cazador de fantasmas       Michelle Paver
# Tuck Everlasting       Natalie Babbitt
# Guardianes de la noche       Sergei Lukyanenko
# Guardianes del crepúsculo       Sergei Lukyanenko
# Animales fantásticos y dónde encontrarlos       Newt Scamander
# --------

# %%
# Lo de antes, pero ahora sólo quiero autores que hayan nacido en 1960 o después

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""
    select ?label ?nameAuthor ?bdate where {
   # ?s a dbo:Book ;
       rdfs:label ?label ;
       dbo:literaryGenre dbr:Fantasy_novel ;
       dbo:author ?author .

   # ?author dbp:name ?nameAuthor ;
           dbp:birthDate ?bdate .

   FILTER(lang(?label) = "es")
   FILTER(?bdate >= "1960-01-01"^^xsd:date)


}  LIMIT 100
  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="       ")
    print()
print("--------")
# Out:
# Princesa mecánica       Cassandra Clare       1973-07-27
# Príncipe mecánico       Cassandra Clare       1973-07-27
# Ángel mecánico       Cassandra Clare       1973-07-27
# Hush, Hush (novela)       Becca Fitzpatrick       1979-02-03
# El pozo de la ascensión       Brandon Sanderson       1975-12-19
# Al filo de las sombras       Brent Weeks       1977-03-07
# Más allá de las sombras (novela)       Brent Weeks       1977-03-07
# El camino de las sombras (novela)       Brent Weeks       1977-03-07
# Skulduggery pleasant       Derek Landy       1974-10-23
# Detective Esqueleto       Derek Landy       1974-10-23
# El amuleto de Samarkanda       Jonathan Stroud       1970-10-27
# El ojo del Golem       Jonathan Stroud       1970-10-27
# Sol de medianoche (novela)       Stephenie Meyer       1973-12-24
# Profundidades       Stephenie Meyer       1973-12-24
# Túneles (novela)       Stephenie Meyer       1973-12-24
# Crepúsculo (novela)       Stephenie Meyer       1973-12-24
# Animales fantásticos y dónde encontrarlos       J. K. Rowling       1965-07-31
# Hermosas criaturas       Kami Garcia       1972-03-25
# Hermosa oscuridad       Kami Garcia       1972-03-25
# Hermoso caos       Kami Garcia       1972-03-25
# Hermano lobo (novela)       Michelle Paver       1960-09-07
# La hechicera (novela)       Michelle Paver       1960-09-07
# El juramento de Torak       Michelle Paver       1960-09-07
# El clan de la foca       Michelle Paver       1960-09-07
# Guardianes de la noche       Sergei Lukyanenko       1968-04-11
# Aleación de ley       Brandon Sanderson       1975-12-19
# Un recuerdo de luz       Brandon Sanderson       1975-12-19
# El héroe de las eras       Brandon Sanderson       1975-12-19
# La tormenta (novela)       Brandon Sanderson       1975-12-19
# Sombras de identidad       Brandon Sanderson       1975-12-19
# El metal perdido       Brandon Sanderson       1975-12-19
# El imperio final       Brandon Sanderson       1975-12-19
# Artemis Fowl: La cuenta atrás       Eoin Colfer       1965-05-14
# Artemis Fowl: La venganza de Opal       Eoin Colfer       1965-05-14
# Artemis Fowl: El Cubo B       Eoin Colfer       1965-05-14
# Artemis Fowl: Encuentro en el Ártico       Eoin Colfer       1965-05-14
# La Orden de la Academia Spence       Libba Bray       1964-03-11
# Eclipse (novela)       Stephenie Meyer       1973-12-24
# Eternidad (novela de Alyson Noël)       Alyson Noël       1965-12-03
# Harry Potter y la cámara secreta (película)       J. K. Rowling       1965-07-31
# Harry Potter y la Orden del Fénix       J. K. Rowling       1965-07-31
# Harry Potter y el prisionero de Azkaban       J. K. Rowling       1965-07-31
# Harry Potter y el cáliz de fuego       J. K. Rowling       1965-07-31
# Harry Potter y la cámara secreta       J. K. Rowling       1965-07-31
# Harry Potter y la piedra filosofal       J. K. Rowling       1965-07-31
# El devorador de almas       Michelle Paver       1960-09-07
# El cazador de fantasmas       Michelle Paver       1960-09-07
# Torres de medianoche       Brandon Sanderson       1975-12-19
# World of Warcraft: Arthas el Ascenso del Rey Exanime       Christie Golden       1963-11-21
# La segunda vida de Bree Tanner       Stephenie Meyer       1973-12-24
# Guardianes del crepúsculo       Sergei Lukyanenko       1968-04-11
# El aliento de los dioses       Brandon Sanderson       1975-12-19
# --------

# %%
# Autores que han escrito algún libro de fantasía y nacidos después de 1960

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""
    select distinct ?nameAuthor ?bdate where {
   # ?s a dbo:Book ;
       rdfs:label ?label ;
       dbo:literaryGenre dbr:Fantasy_novel ;
       dbo:author ?author .

   # ?author dbp:name ?nameAuthor ;
           dbp:birthDate ?bdate .

   FILTER(lang(?label) = "es")
   FILTER(?bdate >= "1960-01-01"^^xsd:date)


}  LIMIT 100
  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="       ")
    print()
print("--------")
# Out:
# Cassandra Clare       1973-07-27
# Becca Fitzpatrick       1979-02-03
# Brandon Sanderson       1975-12-19
# Brent Weeks       1977-03-07
# Derek Landy       1974-10-23
# Jonathan Stroud       1970-10-27
# Stephenie Meyer       1973-12-24
# J. K. Rowling       1965-07-31
# Kami Garcia       1972-03-25
# Michelle Paver       1960-09-07
# Sergei Lukyanenko       1968-04-11
# Eoin Colfer       1965-05-14
# Libba Bray       1964-03-11
# Alyson Noël       1965-12-03
# Christie Golden       1963-11-21
# --------

# %%
# Esos mismos autores pero ordenados por edad de forma descendente

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""
    select distinct ?nameAuthor ?bdate where {
   # ?s a dbo:Book ;
       rdfs:label ?label ;
       dbo:literaryGenre dbr:Fantasy_novel ;
       dbo:author ?author .

   # ?author dbp:name ?nameAuthor ;
           dbp:birthDate ?bdate .

   FILTER(lang(?label) = "es")
   FILTER(?bdate >= "1960-01-01"^^xsd:date)


}  ORDER BY DESC(?bdate)
   LIMIT 100

  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="       ")
    print()
print("--------")
# Out:
# Becca Fitzpatrick       1979-02-03
# Brent Weeks       1977-03-07
# Brandon Sanderson       1975-12-19
# Derek Landy       1974-10-23
# Stephenie Meyer       1973-12-24
# Cassandra Clare       1973-07-27
# Kami Garcia       1972-03-25
# Jonathan Stroud       1970-10-27
# Sergei Lukyanenko       1968-04-11
# Alyson Noël       1965-12-03
# J. K. Rowling       1965-07-31
# Eoin Colfer       1965-05-14
# Libba Bray       1964-03-11
# Christie Golden       1963-11-21
# Michelle Paver       1960-09-07
# --------

# %%
# Todo lo anterior pero, además, quiero saber cuántas novelas de fantasía escribieron cada uno.
# Y, además, ordenaré los resultados por número de novelas, no por fecha de nacimiento

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""
    select  distinct ?nameAuthor ?bdate (count(?s) as ?numBooks) where {
   # ?s a dbo:Book ;
       rdfs:label ?label ;
       dbo:literaryGenre dbr:Fantasy_novel ;
       dbo:author ?author .

   # ?author dbp:name ?nameAuthor ;
           dbp:birthDate ?bdate .

   FILTER(lang(?label) = "es")
   FILTER(?bdate >= "1960-01-01"^^xsd:date)


}  ORDER BY DESC(?numBooks)
   LIMIT 100

  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="       ")
    print()
print("--------")
# Out:
# Brandon Sanderson       1975-12-19       10
# J. K. Rowling       1965-07-31       7
# Michelle Paver       1960-09-07       6
# Stephenie Meyer       1973-12-24       6
# Eoin Colfer       1965-05-14       4
# Brent Weeks       1977-03-07       3
# Cassandra Clare       1973-07-27       3
# Kami Garcia       1972-03-25       3
# Sergei Lukyanenko       1968-04-11       2
# Derek Landy       1974-10-23       2
# Jonathan Stroud       1970-10-27       2
# Christie Golden       1963-11-21       1
# Becca Fitzpatrick       1979-02-03       1
# Libba Bray       1964-03-11       1
# Alyson Noël       1965-12-03       1
# --------

# %% [markdown]
# Prueba en esta última consulta a poner valores distintos al filtro de lengua. O a quitar el filtro de lengua. Esto te ayudará a entender el funcionamiento de count. Auqnue contemos ?s, que representa un libro, no contamos exactamente las URIs de libros. Contamos las veces para las que, para una combinación de ?authorName y ?bdate, que son las otras dos variables de la select, encajan en un patrón nuevo de grafo con todo lo que tenemos en la consulta. Si, por ejemplo, quitas el filtro, saldrá que JK Rowling tiene más de 140 libros. No es así en realidad, ni es así en DBpedia. Pero al tener etiquetas traducidas a muchos lenguajes por cada uno de sus libros, el patrón encaja con distintos datos todas esas veces.
#
#
# Para seguir viendo elemento de SPARQL vamos a quitar el count en las siguientes consultas, para no complicar las cosas más de lo necesario.

# %%
# Autores "jovenes" con libros de fantasía. Si está la información de donde nacieron, que salga. Y si no no pasa nada, que no salga.

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""
    select  distinct ?nameAuthor ?bdate ?place where {
   # ?s a dbo:Book ;
       rdfs:label ?label ;
       dbo:literaryGenre dbr:Fantasy_novel ;
       dbo:author ?author .

   # ?author dbp:name ?nameAuthor ;
           dbp:birthDate ?bdate .

   OPTIONAL { ?author dbp:birthPlace ?place }

   FILTER(lang(?label) = "es")
   FILTER(?bdate >= "1960-01-01"^^xsd:date)


}  ORDER BY DESC(?bdate)
   LIMIT 100

  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="       ")
    print()
print("--------")
# Out:
# Becca Fitzpatrick       1979-02-03
# Brent Weeks       1977-03-07       Montana, USA
# Brandon Sanderson       1975-12-19       Lincoln, Nebraska, U.S.
# Derek Landy       1974-10-23       Lusk, County Dublin, Ireland
# Stephenie Meyer       1973-12-24       Hartford, Connecticut, U.S.
# Cassandra Clare       1973-07-27       Tehran, Iran
# Kami Garcia       1972-03-25
# Jonathan Stroud       1970-10-27       Bedford, England
# Sergei Lukyanenko       1968-04-11       http://dbpedia.org/resource/Karatau,_Kazakhstan
# Sergei Lukyanenko       1968-04-11       http://dbpedia.org/resource/Soviet_Union
# Alyson Noël       1965-12-03       Laguna Beach, California, United States
# J. K. Rowling       1965-07-31       Yate, Gloucestershire, England
# Eoin Colfer       1965-05-14       Wexford, Ireland
# Libba Bray       1964-03-11       http://dbpedia.org/resource/United_States
# Libba Bray       1964-03-11       http://dbpedia.org/resource/Montgomery,_Alabama
# Christie Golden       1963-11-21       Atlanta, Georgia, USA
# Michelle Paver       1960-09-07       Nyasaland
# --------

# %%
# Toda la información y condiciones anteriores. Pero ahora quiero autores con libros de fantasía y/o distopías

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""
    select  distinct ?nameAuthor ?bdate ?place where {
   { ?s a dbo:Book ;
       rdfs:label ?label ;
       dbo:literaryGenre dbr:Fantasy_novel ;
       dbo:author ?author .

   # ?author dbp:name ?nameAuthor ;
           dbp:birthDate ?bdate .

   OPTIONAL { ?author dbp:birthPlace ?place }

   FILTER(lang(?label) = "es")
   FILTER(?bdate >= "1960-01-01"^^xsd:date)
  }

  UNION

  { ?s a dbo:Book ;
       rdfs:label ?label ;
       dbo:literaryGenre dbr:Utopian_and_dystopian_fiction ;
       dbo:author ?author .

   # ?author dbp:name ?nameAuthor ;
           dbp:birthDate ?bdate .

   OPTIONAL { ?author dbp:birthPlace ?place }

   FILTER(lang(?label) = "es")
   FILTER(?bdate >= "1960-01-01"^^xsd:date)
  }

}  ORDER BY DESC(?bdate)
   LIMIT 100

  """
    )


sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="       ")
    print()
print("--------")
# Out:
# Christopher Paolini       1983-11-17       Los Angeles, California, U.S.
# Becca Fitzpatrick       1979-02-03
# Brent Weeks       1977-03-07       Montana, USA
# Brandon Sanderson       1975-12-19       Lincoln, Nebraska, U.S.
# Derek Landy       1974-10-23       Lusk, County Dublin, Ireland
# Stephenie Meyer       1973-12-24       Hartford, Connecticut, U.S.
# Cassandra Clare       1973-07-27       Tehran, Iran
# Ernest Cline       1972-03-29       Ashland, Ohio, U.S.
# Kami Garcia       1972-03-25
# Jonathan Stroud       1970-10-27       Bedford, England
# Dave Eggers       1970-03-12       Boston, Massachusetts, U.S.
# Sergei Lukyanenko       1968-04-11       http://dbpedia.org/resource/Karatau,_Kazakhstan
# Sergei Lukyanenko       1968-04-11       http://dbpedia.org/resource/Soviet_Union
# Alyson Noël       1965-12-03       Laguna Beach, California, United States
# J. K. Rowling       1965-07-31       Yate, Gloucestershire, England
# Eoin Colfer       1965-05-14       Wexford, Ireland
# Libba Bray       1964-03-11       http://dbpedia.org/resource/United_States
# Libba Bray       1964-03-11       http://dbpedia.org/resource/Montgomery,_Alabama
# Christie Golden       1963-11-21       Atlanta, Georgia, USA
# Michelle Paver       1960-09-07       Nyasaland
# --------

# %% [markdown]
# Existen más funciones, más lógica de conjuntos, etc. Pero a partir de aquñi probablemente tenga más sentido consultar documentación de SPARQL si necesitas algo fuera de lo visto.
#
# Queda por abordar el macanismo que, sobre el papel, da tanta potencia por facilidad de integración a los estándares de web semántica: consultas federadas. La posibilidad de mezclar la información de un endpoint con otro.
#
# Para a¡hacer una consulta federada, dentro de nuestra SELECT tenemos que incluir la sentencia SERVICE, seguida por la URL del endpoint objetivo, y entre llaves un atrón de grafo que se debe cumplir en el endpoint objetivo. La gracia es que fuera del service y dentro del service se tendría que estar haciendo referencia a algún elemento común (una URI presente en ambos endpoints) que me permita unir los grafos.
#
# Para este ejemplo, no obstante, no podemos usar el endpoint de DBpedia como base. El endpoint público de DBpedia (la instalación de ese endpoint, no el motor Virtuoso por defecto) no permite federación como medida de seguridad. El siguietne código (fallará) es sintaxis válida para sacar las propiedades que haya en Wikidata de cualqueir libro de Brandon Sanderson que tenga un enlace explícito de DBpedia a Wikidata:

# %%
# Información en Wikidata de libros de Brandon Sanderson que están en DPbedia

from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""

    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX wd: <http://www.wikidata.org/entity/>

select  distinct ?nameAuthor ?p ?o where {
   # ?s a dbo:Book ;
       rdfs:label ?label ;
       dbo:author ?Brandon_Sanderson ;
       owl:sameAs ?wikiURI .

    SERVICE <https://query.wikidata.org/sparql> {
      # ?wikiURI    wdt:P50 wd:Q28392 ;  # P50 = Autor, Q28392 = Brandon Sanderson
                  wdt:P31 wd:Q571 ;  # P31 = Instancia de, Q571 = Libro
                  # ?p ?o .
    }
}  LIMIT 100

  """
    )
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="       ")
    print()
print("--------")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     925             else:
# --> 926                 response = urlopener(request)
#     927             return response, self.returnFormat
#
# /usr/lib/python3.11/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#
# /usr/lib/python3.11/urllib/request.py in open(self, fullurl, data, timeout)
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#
# /usr/lib/python3.11/urllib/request.py in http_response(self, request, response)
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#
# /usr/lib/python3.11/urllib/request.py in error(self, proto, *args)
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#
# /usr/lib/python3.11/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#
# /usr/lib/python3.11/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#
# /usr/lib/python3.11/urllib/request.py in open(self, fullurl, data, timeout)
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#
# /usr/lib/python3.11/urllib/request.py in http_response(self, request, response)
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#
# /usr/lib/python3.11/urllib/request.py in error(self, proto, *args)
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#
# /usr/lib/python3.11/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#
# /usr/lib/python3.11/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#
# HTTPError: HTTP Error 500: SPARQL Request Failed
#
# During handling of the above exception, another exception occurred:
#
# EndPointInternalError                     Traceback (most recent call last)
# <ipython-input-65-327ba898ddee> in <cell line: 0>()
#      32
#      33 sparql.setReturnFormat(JSON)
# ---> 34 results = sparql.query().convert()
#      35 for result in results["results"]["bindings"]:
#      36     for a_var_key in result:
#
# /usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py in query(self)
#     958         :rtype: :class:`QueryResult` instance
#     959         """
# --> 960         return QueryResult(self._query())
#     961
#     962     def queryAndConvert(self) -> "QueryResult.ConvertResult":
#
# /usr/local/lib/python3.11/dist-packages/SPARQLWrapper/Wrapper.py in _query(self)
#     936                 raise URITooLong(e.read())
#     937             elif e.code == 500:
# --> 938                 raise EndPointInternalError(e.read())
#     939             else:
#     940                 raise e
#
# EndPointInternalError: EndPointInternalError: The endpoint returned the HTTP status code 500.
#
# Response:
# b'Virtuoso 42000 Error SQ070:SECURITY: Must have SELECT privileges on view DB.DBA.SPARQL_SINV_2 for group ID 111 (SPARQL), user ID 111 (SPARQL)\n\nSPARQL query:\n#output-format:application/sparql-results+json\n\n\n    PREFIX wdt: <http://www.wikidata.org/prop/direct/>\n    PREFIX wd: <http://www.wikidata.org/entity/>\n\n    select  distinct ?nameAuthor ?bdate ?place where {\n   ?s a dbo:Book ;\n       rdfs:label ?label ;\n       dbo:author ?Brandon_Sanderson ;\n       owl:sameAs ?wikiURI .\n      \n    SERVICE <https://query.wikidata.org/sparql> {\n      ?wikiURI    wdt:P50 wd:Q28392 ;  # P50 = Autor, Q28392 = Brandon Sanderson\n                  wdt:P31 wd:Q571 ;  # P31 = Instancia de, Q571 = Libro\n                  ?p ?o .\n                      \n                  \n    }\n\n   \n}  LIMIT 100\n   \n  \n'

# %% [markdown]
# Como ves en la traza de error, esto no funciona por algo relacionado con permisos, no tiene nada que ver con como de conectada está la información a nivel de datos. De hecho, si intentamos hacer esto mismo pero al revés, es decir, tirar esta consulta contra el endpoint de Wikidata tratando de federar el endpoint de DBpedia, sí podemos ejecutar la consulta.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")  # Construimos un objeto para acceder a cierto endpoint. En este caso, DBpedia
sparql.setQuery("""

prefix wdt: <http://www.wikidata.org/prop/direct/>
prefix wd: <http://www.wikidata.org/entity/>
prefix wikibase: <http://wikiba.se/ontology#>
prefix dbr: <http://dbpedia.org/resource/>
prefix dbo: <http://dbpedia.org/ontology/>
prefix dbp: <http://dbpedia.org/property/>

SELECT DISTINCT ?obra_dbpedia ?p ?o WHERE {
  # ?obra_wikidata wdt:P50 wd:Q457608 ;
                 wdt:P31 wd:Q1667921 ;
                 # ?p ?o .

  SERVICE <http://dbpedia.org/sparql> {
    # ?obra_dbpedia owl:sameAs ?obra_wikidata ;
                  dbp:author dbr:Brandon_Sanderson .

  }

} LIMIT 100

  """
    )

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    for a_var_key in result:
      print(result[a_var_key]["value"], end="       ")
    print()
print("--------")
# Out:
# http://schema.org/version       2299571138       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       knižní fantasy série Roberta Jordana       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       La roda del temps       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Кола Часу       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       RdT       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       WoT       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       Dodecalogia de noveŀles de fantasia d'en Robert Jordan       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Ο Τροχός του Χρόνου       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       fantáziaregény-sorozat       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       WoT       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       zbirka fantazijskih romanov Roberta Jordana       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Kolo časa       http://dbpedia.org/resource/The_Wheel_of_Time
# http://wikiba.se/ontology#statements       59       http://dbpedia.org/resource/The_Wheel_of_Time
# http://wikiba.se/ontology#sitelinks       38       http://dbpedia.org/resource/The_Wheel_of_Time
# http://wikiba.se/ontology#identifiers       26       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Rad der Zeit       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       La rueda del tiempo       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       La Roue du temps       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       時間之輪       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       چرخ زمان       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       時光之輪       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Das Rad der Zeit       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Koło Czasu       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Vita tornet       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       סדרת ספרי פנטזיה       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       عجلة الزمن       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       מחזור כישור הזמן       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Az Idő Kereke       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       La Ruota del Tempo       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       時の車輪       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Sagan om Drakens återkomst       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Колесо часу       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Zaman Çarkı       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       سلسلة روايات خيال علمي       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       сэрыя фэнтэзійных раманаў пісьменьніка Робэрта Джордана       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Кола часу       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Колелото на времето       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Rod an amzer       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Točak vremena       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Wheel Of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Kolo času       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       Romanzyklus von Robert Jordan       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       WoT       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       series of fantasy novels by Robert Jordan       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       serio de fantastaj romanoj far Roberto Jordano       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       La Rado de Tempo       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       saga literaria creada por Robert Jordan       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Myrddraali       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Trollokki       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       سری رمان خیالپردازی حماسی اثر نویسنده آمریکایی جیمز الیور ریگنی جونیور با تخلص رابرت جوردن       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       Robert Jordanin fantasiaromaanisarja       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Ajan pyörä       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       série de romans de fantasy écrite par Robert Jordan       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       כישור הזמן       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       A Roda do Tempo       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Il Pugnale dei Sogni       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       L’Ascesa dell’Ombra       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       serie di romanzi fantasy scritta da Robert Jordan       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       დროის ბორბალი       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Rota Temporis       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       The Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Rad des tijds       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       fantasy-serie       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       The wheel of time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       पुस्तक श्रृंखला       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Tidshjulet       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       boekenserie van Robert Jordan       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       वोत       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Het Rad des Tijds       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Tidshjulet       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Roata Timpului       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       A Roda do Tempo       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       série de alta fantasia criado por Robert Jordan       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Колесо времён       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       serie de romane fantastice de Robert Jordan, completată de Brandon Sanderson       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Roata timpului       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Колесо Времени       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Točak vremena       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Drakens återkomst       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Osan'gar       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       Wheel of Time       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       Точак времена       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/description       fantasy-bokserie skriven av Robert Jordan       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2004/02/skos/core#altLabel       时光之轮       http://dbpedia.org/resource/The_Wheel_of_Time
# http://www.w3.org/2000/01/rdf-schema#label       時間之輪       http://dbpedia.org/resource/The_Wheel_of_Time
# http://schema.org/dateModified       2025-01-18T21:25:33Z       http://dbpedia.org/resource/The_Wheel_of_Time
# --------
